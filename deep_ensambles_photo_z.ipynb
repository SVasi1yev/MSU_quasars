# %%
import pickle
import time

import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from tqdm import tqdm

from astropy.table import Table

# %%
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader

# %%
data_dir = 'data'
with open(f'{data_dir}/features_sdssdr16+psdr2+all_deacls8tr_QSO+GALAXY_20201212133711.pkl', 'rb') as f:
    features_list = pickle.load(f)
models_cols = ['max19_z', 'conf19_z', 'max21_z', 'conf21_z', 'max22_z', 'conf22_z', 'max35_z', 'conf35_z']

# %%
np.random.seed(0)
torch.manual_seed(0)

# %%
train_20 = pd.read_csv(f'{data_dir}/q_photo_z_train_20.csv')

# %%
train_20
# Out:
#                 RA        DEC         Z  sdssdr16_u_psf  sdssdr16_g_psf  \
# 0         0.000722  11.343983  0.442757       23.376900       22.425905
# 1         0.001417  18.492306  0.629820       22.113601       22.968215
# 2         0.001885  17.773712  2.309000       22.265783       21.813904
# 3         0.002416   5.941882  2.103120       22.059562       21.434419
# 4         0.002769  14.974691  2.497000       21.761608       21.095956
# ...            ...        ...       ...             ...             ...
# 580451  359.998949  10.116818  2.415000       23.056658       21.692741
# 580452  359.999026  24.413551  1.490065       20.921111       20.732991
# 580453  359.999121  28.954727  2.452000       21.876842       21.168578
# 580454  359.999634   3.268618  1.233161       18.791953       18.815835
# 580455  359.999759  20.721092  2.009941       20.073821       20.125445
#
#         sdssdr16_r_psf  sdssdr16_i_psf  sdssdr16_z_psf  sdssdr16_u_cmodel  \
# 0            20.799930       20.031074       19.622680          20.226514
# 1            21.524378       20.363373       19.827644          22.126405
# 2            21.999912       21.870190       21.266889          22.343590
# 3            21.211019       21.184635       20.688257          22.046778
# 4            20.797531       20.715893       20.589152          21.633194
# ...                ...             ...             ...                ...
# 580451       21.373058       21.151950       21.260001          21.525019
# 580452       20.529058       20.355686       20.119849          20.765828
# 580453       21.233727       21.235761       20.713764          21.639407
# 580454       18.557703       18.614296       18.673656          18.798606
# 580455       20.113292       19.918278       19.768315          20.061213
#
#         sdssdr16_i_cmodel  ...  sdssdr16_z_cmodel-decals8tr_z   max19_z  \
# 0               19.305746  ...                       0.434388  0.474689
# 1               19.405817  ...                      -0.151581  0.599155
# 2               21.853381  ...                      -0.287098  2.322151
# 3               21.198729  ...                      -0.543980  0.846000
# 4               20.676625  ...                      -0.086858  2.320000
# ...                   ...  ...                            ...       ...
# 580451          21.153138  ...                       0.502369  2.343000
# 580452          20.362367  ...                      -0.534182  1.696801
# 580453          21.276328  ...                      -0.513353  2.360000
# 580454          18.611784  ...                      -0.625142  1.261000
# 580455          19.926544  ...                      -0.028731  2.187629
#
#         conf19_z   max21_z  conf21_z   max22_z  conf22_z   max35_z  conf35_z  \
# 0       0.928341  0.458632  0.936633  0.419659  0.636504  0.447622  0.961682
# 1       0.926998  0.647224  0.999999  0.708078  0.910233  0.604697  0.955222
# 2       0.312809  2.300145  0.422922  2.368000  0.576355  2.121082  0.503914
# 3       0.331083  0.819000  0.382401  0.916635  0.653894  0.801000  0.485579
# 4       0.558577  2.482500  0.664471  2.625000  0.634396  2.404000  0.824371
# ...          ...       ...       ...       ...       ...       ...       ...
# 580451  0.448830  2.362000  0.289139  2.620000  0.275886  2.598000  0.508071
# 580452  0.276569  1.516000  0.353289  1.471000  0.272345  1.519121  0.532895
# 580453  0.368830  2.349000  0.583509  2.416101  0.459684  2.333000  0.827930
# 580454  0.765830  1.264800  0.803640  1.163000  0.854128  1.319833  0.751813
# 580455  0.706492  2.203455  0.461592  2.204818  0.332097  1.956595  0.967376
#
#         fold
# 0          0
# 1          0
# 2          1
# 3          1
# 4          0
# ...      ...
# 580451     0
# 580452     0
# 580453     1
# 580454     0
# 580455     0
#
# [580456 rows x 77 columns]

# %%
device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')

# %%
class SimpleDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y
        if self.X.shape[0] != self.y.shape[0]:
            raise ValueError
        
    def __len__(self):
        return self.X.shape[0]
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
class MLP(nn.Module):
    def __init__(self, sizes, p):
        super().__init__()
        self.sizes = sizes
        layers = []
        for i in range(1, len(sizes)):
            if i > 1:
                layers.append(nn.ReLU())
                layers.append(nn.Dropout(p))
            layers.append(nn.Linear(self.sizes[i-1], self.sizes[i], bias=False))
            if i < len(sizes) - 1:
                layers.append(nn.BatchNorm1d(self.sizes[i]))
        self.layers = nn.Sequential(*layers)
        self.layers.apply(self.init_weights)
        
    def init_weights(self, m):
        if isinstance(m, nn.Linear):
            torch.nn.init.kaiming_uniform_(m.weight, nonlinearity='relu')
                          
    def forward(self, x, train_m):
        self.train(train_m)
        out = self.layers(x)
        mean, var = out[:, 0], out[:, 1]
        return mean, var
    
    def run_epoch(self, dataloader, optimizer=None, loss_f=None):
        train_m = (optimizer is not None) and (loss_f is not None)
        true, mean, var = [], [], []
        for X, y in dataloader:
            if train_m:
                optimizer.zero_grad()
            batch_mean, batch_var = self(X, train_m)
            # batch_out = self(X)
            # batch_mean, batch_var = batch_out[:, 0], batch_out[:, 1]
            if train_m:
                loss = loss_f(y, batch_mean, batch_var)
                loss.backward()
                optimizer.step()
            true.append(y.cpu().detach().numpy().reshape(-1))
            mean.append(batch_mean.cpu().detach().numpy().reshape(-1))
            var.append(batch_var.cpu().detach().numpy().reshape(-1))
        true = np.concatenate(true)
        mean = np.concatenate(mean)
        var = np.concatenate(var)
        return true, mean, var
                          
#     def fit(self, train_dataloader, test_dataloader, epochs, optimizer, loss_f, metrics=[]):
#         for epoch in range(epochs):
#             print(f'Epoch #{epoch+1}/{epochs}')
#             start = time.time()
#             train_loss, test_loss = 0, 0
#             batch_num = 0
#             preds = []
#             true = []
#             for X, y in train_dataloader:
#                 batch_num += 1
#                 optimizer.zero_grad()
#                 outputs = self(X)
#                 mean, var = outputs[:, 0], outputs[:, 1]
#                 loss = loss_f(y, mean, var)
#                 train_loss += loss.item()
#                 loss.backward()
#                 optimizer.step()
#                 preds.append(mean.cpu().detach().numpy().reshape(-1))
#                 true.append(y.cpu().detach().numpy().reshape(-1))
#             train_loss /= batch_num
#             print(f'Train loss: {round(train_loss, 5)}\t', end='')
            
#             preds = np.concatenate(preds)
#             true = np.concatenate(true)
#             for metric in metrics:
#                 print(f'Train {metric}: {round(metrics[metric](true, preds), 5)}\t', end='')
#             print()
                
#             batch_num = 0
#             preds = []
#             true = []
#             for X, y in test_dataloader:
#                 batch_num += 1
#                 outputs = self(X)
#                 mean, var = outputs[:, 0], outputs[:, 1]
#                 loss = loss_f(y, mean, var)
#                 test_loss += loss.item()
#                 preds.append(mean.cpu().detach().numpy().reshape(-1))
#                 true.append(y.cpu().detach().numpy().reshape(-1))
#             test_loss /= batch_num
#             print(f'Test  loss: {round(test_loss, 5)}\t', end='')
            
#             preds = np.concatenate(preds)
#             true = np.concatenate(true)
#             for metric in metrics:
#                 print(f'Test  {metric}: {round(metrics[metric](true, preds), 5)}\t', end='')
#             print()
#             print(f'Time: {round(time.time() - start, 5)}')
#             print('=' * 30)
    
    @classmethod
    def get_dataloader(cls, X, y, batch_size=2**13, shuffle=True):
        order = np.arange(X.shape[0], dtype=int)
        if shuffle:
            np.random.shuffle(order)
        dataset = SimpleDataset(X, y)
        dataloader = DataLoader(dataset, batch_size, shuffle=False)
        return dataloader

# %%
class DeepEnsemble:
    def __init__(self, BaseModel, base_model_args, M, device=torch.device('cpu')):
        self.BaseModel = BaseModel
        self.base_model_args = base_model_args
        self.M = M
        self.device = device
        self.models = []
        for i in range(M):
            self.models.append(self.BaseModel(**self.base_model_args).to(self.device))
        
    def loss(self, y, mean, var):
        if isinstance(y, torch.Tensor):
            return ((var + torch.exp(-var) * (mean - y)**2) / 2).mean()
        else:
            return ((var + np.exp(-var) * (mean - y)**2) / 2).mean()
                
    def fit(
        self, X_train, y_train, X_test=None, y_test=None, 
        epochs=5, batch_size=2**13, shuffle=True, 
        optimizer=torch.optim.Adam, optimizer_args={'lr': 0.0005, 'weight_decay': 0.0001}, 
        verbose=True, metrics=[]
    ):
        print(f'Device: {self.device}')
        X_train_tensor = torch.tensor(X_train, device=torch.device(device), dtype=torch.float)
        y_train_tensor = torch.tensor(y_train, device=torch.device(device), dtype=torch.float)
        X_test_tensor = torch.tensor(X_test, device=torch.device(device), dtype=torch.float)
        y_test_tensor = torch.tensor(y_test, device=torch.device(device), dtype=torch.float)
        
        test_dataloader = self.BaseModel.get_dataloader(
            X_test_tensor, y_test_tensor,
            batch_size=batch_size, shuffle=shuffle
        )
        
        test_m = (X_test is not None) and (y_test is not None)
        print(f'Test mode: {test_m}')
        print('=' * 40)
        
        optimizers = []
        for model in self.models:
            optimizers.append(optimizer(model.parameters(), **optimizer_args))

        train_metric_vals = {metric: [] for metric in metrics}
        train_losses = []
        if test_m:
            test_metric_vals = {metric: [] for metric in metrics}
            test_losses = []
        else:
            test_metric_vals = None
            test_losses = None
    
        for epoch in range(epochs):
            print(f'EPOCH #{epoch+1}/{epochs}:')
            print('-' * 40)
            start = time.time()
            
            #TRAIN
            
            train_dataloader = self.BaseModel.get_dataloader(
                X_train_tensor, y_train_tensor,
                batch_size=batch_size, shuffle=shuffle
            )
            
            epoch_mean, epoch_var = [], []
            epoch_losses = []
            for i, model in enumerate(self.models):
                epoch_true, m, v = model.run_epoch(train_dataloader, optimizers[i], self.loss)
                epoch_mean.append(m)
                epoch_var.append(v)
                epoch_losses.append(self.loss(epoch_true, m, v).item())
            t_m = np.array(epoch_mean)
            epoch_mean = np.mean(t_m, axis=0)
            t_v = np.array(epoch_var)
            epoch_var = np.mean(t_v, axis=0) + np.mean(t_m - epoch_mean, axis=0)
            
            train_losses.append(epoch_losses)
            if verbose:
                print(f'Trian losses: {[round(l, 5) for l in epoch_losses]}')
                print(f'AVG train loss: {round(np.mean(epoch_losses), 5)}')
            
            for metric in metrics:
                train_metric_vals[metric].append(metrics[metric](epoch_true, epoch_mean))    
            if verbose:
                for metric in metrics:
                      print(f'Train {metric}: {round(train_metric_vals[metric][-1], 5)}\t', end='')
                print()
            print('-' * 40)
                
            #TEST
            if test_m:     
                epoch_mean, epoch_var = [], []
                epoch_losses = []
                for i, model in enumerate(self.models):
                    epoch_true, m, v = model.run_epoch(test_dataloader)
                    epoch_mean.append(m)
                    epoch_var.append(v)
                    epoch_losses.append(self.loss(epoch_true, m, v).item())
                t_m = np.array(epoch_mean)
                epoch_mean = np.mean(t_m, axis=0)
                t_v = np.array(epoch_var)
                epoch_var = np.mean(t_v, axis=0) + np.mean(t_m - epoch_mean, axis=0)

                test_losses.append(epoch_losses)
                if verbose:
                    print(f'Test losses: {[round(l, 5) for l in epoch_losses]}')
                    print(f'AVG test loss: {round(np.mean(epoch_losses), 5)}')

                for metric in metrics:
                    test_metric_vals[metric].append(metrics[metric](epoch_true, epoch_mean))    
                if verbose:
                    for metric in metrics:
                          print(f'Test {metric}: {round(test_metric_vals[metric][-1], 5)}\t', end='')
                    print()
                print('-' * 40)
            
            print(f'Time: {round(time.time() - start, 3)}')
            print('=' * 40)
        return train_metric_vals, train_losses, test_metric_vals, test_losses

# %%
def sigma_nmad(true, preds):
    diff = preds - true
    m = np.median(diff)
    return 1.48 * np.median(np.abs((diff - m) / (1 + true)))

# %%
def out_rate(true, preds):
    diff = preds - true
    return ((np.abs(diff) / (1 + true)) > 0.15).sum() / len(true)

# %%
train_20_35_01 = train_20[train_20['fold'] == 0].dropna()[['RA', 'DEC', 'Z'] + features_list + ['max35_z', 'conf35_z']]
X_01, y_01 = train_20_35_01[features_list].values.astype(float), train_20_35_01['Z'].values.astype(float)
train_20_35_02 = train_20[train_20['fold'] == 1].dropna()[['RA', 'DEC', 'Z'] + features_list + ['max35_z', 'conf35_z']]
X_02, y_02 = train_20_35_02[features_list].values.astype(float), train_20_35_02['Z'].values.astype(float)

# %%
ens = DeepEnsemble(
    MLP, 
    {'sizes': [X_01.shape[1], 256, 256, 256, 256, 2], 'p': 0.0},
    10, device
)
optimizer = torch.optim.Adam

# %%
ens.fit(
    X_train=X_01, 
    y_train=y_01,
    X_test=X_02,
    y_test=y_02,
    epochs=100, 
    batch_size=2**15,
    shuffle=True,
    optimizer=optimizer, 
    optimizer_args={'lr': 0.0005, 'weight_decay': 0.001},
    verbose=True,
    metrics={'S_nmad': sigma_nmad, 'out_rate': out_rate}
);
# Out:
# Device: cuda:0
# Test mode: True
# ========================================
# EPOCH #1/100:
# ----------------------------------------
# Trian losses: [1.64056, 0.38958, 0.70891, 1.61283, 1.38108, 0.89885, 255.02843, 2.44769, 2309.33301, 3.28835]
# AVG train loss: 257.67293
# Train S_nmad: 0.33198	Train out_rate: 0.94697
# ----------------------------------------
# Test losses: [11.50263, 2.85191, 6.61537, 3.98491, 5.29903, 3.74524, 5.81755, 1.8631, 1.9196, 2.80928]
# AVG test loss: 4.64086
# Test S_nmad: 0.47804	Test out_rate: 1.0
# ----------------------------------------
# Time: 63.168
# ========================================
# EPOCH #2/100:
# ----------------------------------------
# Trian losses: [0.69954, -0.01786, 0.25523, 0.55079, 0.72381, 0.41742, 2.34544, 0.46079, 1.65502, 0.70414]
# AVG train loss: 0.77943
# Train S_nmad: 0.28626	Train out_rate: 0.79282
# ----------------------------------------
# Test losses: [5.26351, 0.45423, 1.90966, 2.45757, 2.03233, 2.05639, 1.88344, 1.3178, 1.69179, 1.2053]
# AVG test loss: 2.0272
# Test S_nmad: 0.55758	Test out_rate: 0.95663
# ----------------------------------------
# Time: 63.559
# ========================================
# EPOCH #3/100:
# ----------------------------------------
# Trian losses: [0.5304, -0.30971, -0.02082, 0.40441, 0.55644, 0.15166, 1.65952, 0.33076, 1.05036, 0.34091]
# AVG train loss: 0.46939
# Train S_nmad: 0.23946	Train out_rate: 0.65484
# ----------------------------------------
# Test losses: [1.69246, -0.03677, 0.26541, 0.89228, 0.72782, 0.51418, 1.08439, 0.60561, 1.07526, 0.64083]
# AVG test loss: 0.74615
# Test S_nmad: 0.35612	Test out_rate: 0.72048
# ----------------------------------------
# Time: 59.564
# ========================================
# EPOCH #4/100:
# ----------------------------------------
# Trian losses: [0.36794, -0.5142, -0.28482, 0.28384, 0.38277, -0.12956, 1.26277, 0.24245, 0.74555, 0.22687]
# AVG train loss: 0.25836
# Train S_nmad: 0.19704	Train out_rate: 0.55257
# ----------------------------------------
# Test losses: [0.62864, -0.32417, -0.23635, 0.31865, 0.35947, 0.10519, 1.04198, 0.2464, 0.77566, 0.27848]
# AVG test loss: 0.31939
# Test S_nmad: 0.22548	Test out_rate: 0.57474
# ----------------------------------------
# Time: 62.789
# ========================================
# EPOCH #5/100:
# ----------------------------------------
# Trian losses: [0.18848, -0.65786, -0.49872, 0.16666, 0.18445, -0.37647, 1.02141, 0.15555, 0.58448, 0.15122]
# AVG train loss: 0.09192
# Train S_nmad: 0.1672	Train out_rate: 0.47712
# ----------------------------------------
# Test losses: [0.21104, -0.52068, -0.43005, 0.08595, 0.16078, -0.17132, 0.90738, 0.10126, 0.58044, 0.15736]
# AVG test loss: 0.10822
# Test S_nmad: 0.16823	Test out_rate: 0.47001
# ----------------------------------------
# Time: 65.289
# ========================================
# EPOCH #6/100:
# ----------------------------------------
# Trian losses: [0.0095, -0.76056, -0.62096, 0.04331, -0.02615, -0.55718, 0.85667, 0.06635, 0.48741, 0.08999]
# AVG train loss: -0.04116
# Train S_nmad: 0.14792	Train out_rate: 0.42289
# ----------------------------------------
# Test losses: [-0.01262, -0.59188, -0.58216, -0.06609, -0.05029, -0.42205, 0.78124, -0.00303, 0.45677, 0.05908]
# AVG test loss: -0.0431
# Test S_nmad: 0.14395	Test out_rate: 0.38894
# ----------------------------------------
# Time: 61.163
# ========================================
# EPOCH #7/100:
# ----------------------------------------
# Trian losses: [-0.15601, -0.81054, -0.7298, -0.07863, -0.22875, -0.63766, 0.74098, -0.02315, 0.41603, 0.02654]
# AVG train loss: -0.1481
# Train S_nmad: 0.13367	Train out_rate: 0.3788
# ----------------------------------------
# Test losses: [-0.21286, -0.68889, -0.43341, -0.17696, -0.27865, -0.38727, 0.68507, -0.09229, 0.37416, -0.02033]
# AVG test loss: -0.12314
# Test S_nmad: 0.12677	Test out_rate: 0.33503
# ----------------------------------------
# Time: 63.484
# ========================================
# EPOCH #8/100:
# ----------------------------------------
# Trian losses: [-0.29721, -0.84696, -0.77271, -0.19293, -0.40137, -0.70287, 0.65678, -0.10751, 0.35945, -0.03478]
# AVG train loss: -0.23401
# Train S_nmad: 0.12543	Train out_rate: 0.33442
# ----------------------------------------
# Test losses: [-0.35113, -0.70395, -0.62875, -0.27705, -0.41558, -0.54939, 0.61146, -0.17129, 0.31579, -0.07603]
# AVG test loss: -0.22459
# Test S_nmad: 0.11925	Test out_rate: 0.2956
# ----------------------------------------
# Time: 61.806
# ========================================
# EPOCH #9/100:
# ----------------------------------------
# Trian losses: [-0.42291, -0.82455, -0.819, -0.29852, -0.53273, -0.67686, 0.59155, -0.18727, 0.31305, -0.09585]
# AVG train loss: -0.29531
# Train S_nmad: 0.11736	Train out_rate: 0.3015
# ----------------------------------------
# Test losses: [-0.40983, -0.60525, -0.51849, -0.36587, -0.49404, -0.62763, 0.55131, -0.2445, 0.27173, -0.13725]
# AVG test loss: -0.25798
# Test S_nmad: 0.10977	Test out_rate: 0.26448
# ----------------------------------------
# Time: 63.237
# ========================================
# EPOCH #10/100:
# ----------------------------------------
# Trian losses: [-0.47639, -0.89741, -0.85755, -0.39122, -0.62137, -0.76829, 0.538, -0.26067, 0.27334, -0.15619]
# AVG train loss: -0.36177
# Train S_nmad: 0.11115	Train out_rate: 0.27026
# ----------------------------------------
# Test losses: [-0.33229, -0.69222, -0.8118, -0.44649, -0.61346, -0.79036, 0.49908, -0.30897, 0.23469, -0.1983]
# AVG test loss: -0.34601
# Test S_nmad: 0.10867	Test out_rate: 0.2464
# ----------------------------------------
# Time: 63.526
# ========================================
# EPOCH #11/100:
# ----------------------------------------
# Trian losses: [-0.55886, -0.94756, -0.82402, -0.46931, -0.66666, -0.79362, 0.49159, -0.32679, 0.23781, -0.21435]
# AVG train loss: -0.40718
# Train S_nmad: 0.106	Train out_rate: 0.24425
# ----------------------------------------
# Test losses: [-0.54643, -0.93126, -0.70601, -0.5177, -0.68478, -0.77228, 0.45216, -0.36438, 0.20102, -0.25878]
# AVG test loss: -0.41284
# Test S_nmad: 0.10251	Test out_rate: 0.22321
# ----------------------------------------
# Time: 61.134
# ========================================
# EPOCH #12/100:
# ----------------------------------------
# Trian losses: [-0.64693, -1.00343, -0.83582, -0.53368, -0.71216, -0.81962, 0.44952, -0.38642, 0.20539, -0.27008]
# AVG train loss: -0.45532
# Train S_nmad: 0.1029	Train out_rate: 0.22313
# ----------------------------------------
# Test losses: [-0.54313, -0.95209, -0.80861, -0.58254, -0.73916, -0.50905, 0.40933, -0.41249, 0.17001, -0.31652]
# AVG test loss: -0.42843
# Test S_nmad: 0.10095	Test out_rate: 0.21232
# ----------------------------------------
# Time: 63.417
# ========================================
# EPOCH #13/100:
# ----------------------------------------
# Trian losses: [-0.64808, -1.04602, -0.83894, -0.58662, -0.75623, -0.84646, 0.41018, -0.44078, 0.17545, -0.32326]
# AVG train loss: -0.49008
# Train S_nmad: 0.09649	Train out_rate: 0.20456
# ----------------------------------------
# Test losses: [-0.57894, -0.52081, -0.7474, -0.6404, -0.73895, -0.8362, 0.36945, -0.45511, 0.14117, -0.37022]
# AVG test loss: -0.43774
# Test S_nmad: 0.09565	Test out_rate: 0.18192
# ----------------------------------------
# Time: 61.248
# ========================================
# EPOCH #14/100:
# ----------------------------------------
# Trian losses: [-0.70197, -0.73959, -0.87992, -0.63051, -0.76728, -0.93964, 0.37267, -0.4905, 0.14731, -0.37343]
# AVG train loss: -0.50029
# Train S_nmad: 0.09312	Train out_rate: 0.18933
# ----------------------------------------
# Test losses: [-0.61259, -0.47847, -0.81524, -0.69177, -0.65683, -0.8472, 0.33168, -0.49495, 0.11401, -0.421]
# AVG test loss: -0.45724
# Test S_nmad: 0.0963	Test out_rate: 0.19077
# ----------------------------------------
# Time: 59.322
# ========================================
# EPOCH #15/100:
# ----------------------------------------
# Trian losses: [-0.77996, -0.82421, -0.93647, -0.66838, -0.79369, -0.97106, 0.33651, -0.53616, 0.12057, -0.42042]
# AVG train loss: -0.54733
# Train S_nmad: 0.09154	Train out_rate: 0.17899
# ----------------------------------------
# Test losses: [-0.70655, -0.64444, -0.92707, -0.73128, -0.74669, -0.92667, 0.29595, -0.53535, 0.08826, -0.46951]
# AVG test loss: -0.53033
# Test S_nmad: 0.08854	Test out_rate: 0.17637
# ----------------------------------------
# Time: 60.801
# ========================================
# EPOCH #16/100:
# ----------------------------------------
# Trian losses: [-0.81515, -0.86907, -0.95905, -0.70571, -0.85177, -0.98921, 0.30138, -0.57853, 0.09501, -0.46501]
# AVG train loss: -0.58371
# Train S_nmad: 0.08842	Train out_rate: 0.16966
# ----------------------------------------
# Test losses: [-0.75709, -0.80081, -0.86681, -0.74199, -0.79602, -0.93645, 0.26177, -0.57176, 0.06364, -0.51465]
# AVG test loss: -0.56602
# Test S_nmad: 0.08525	Test out_rate: 0.16458
# ----------------------------------------
# Time: 61.45
# ========================================
# EPOCH #17/100:
# ----------------------------------------
# Trian losses: [-0.85954, -0.8997, -0.99649, -0.746, -0.89159, -1.01727, 0.26696, -0.61602, 0.07042, -0.5069]
# AVG train loss: -0.61961
# Train S_nmad: 0.08495	Train out_rate: 0.15991
# ----------------------------------------
# Test losses: [-0.85929, -0.86867, -0.98389, -0.72991, -0.9039, -0.94145, 0.22831, -0.59344, 0.03981, -0.56469]
# AVG test loss: -0.61771
# Test S_nmad: 0.07893	Test out_rate: 0.15008
# ----------------------------------------
# Time: 59.62
# ========================================
# EPOCH #18/100:
# ----------------------------------------
# Trian losses: [-0.91186, -0.92136, -1.00288, -0.78353, -0.94298, -1.00235, 0.23298, -0.64712, 0.04663, -0.54584]
# AVG train loss: -0.64783
# Train S_nmad: 0.08156	Train out_rate: 0.15088
# ----------------------------------------
# Test losses: [-0.87593, -0.88214, -1.03043, -0.77004, -0.90697, -0.94622, 0.19503, -0.60761, 0.01657, -0.61848]
# AVG test loss: -0.64262
# Test S_nmad: 0.07594	Test out_rate: 0.14169
# ----------------------------------------
# Time: 59.382
# ========================================
# EPOCH #19/100:
# ----------------------------------------
# Trian losses: [-0.96843, -0.95889, -1.04038, -0.82188, -0.97244, -1.01053, 0.1993, -0.67343, 0.02351, -0.58974]
# AVG train loss: -0.68129
# Train S_nmad: 0.07773	Train out_rate: 0.14152
# ----------------------------------------
# Test losses: [-0.87506, -0.90565, -1.00126, -0.82427, -0.95839, -0.85281, 0.16178, -0.62126, -0.00609, -0.63748]
# AVG test loss: -0.65205
# Test S_nmad: 0.07619	Test out_rate: 0.14104
# ----------------------------------------
# Time: 59.86
# ========================================
# EPOCH #20/100:
# ----------------------------------------
# Trian losses: [-0.87057, -0.96869, -1.03812, -0.85621, -0.98532, -0.99159, 0.16584, -0.6948, 0.00099, -0.63746]
# AVG train loss: -0.68759
# Train S_nmad: 0.07575	Train out_rate: 0.13796
# ----------------------------------------
# Test losses: [-0.48619, -0.9103, -0.96849, -0.85555, -1.01782, -0.88766, 0.12849, -0.65748, -0.02823, -0.6684]
# AVG test loss: -0.63516
# Test S_nmad: 0.07721	Test out_rate: 0.14204
# ----------------------------------------
# Time: 57.482
# ========================================
# EPOCH #21/100:
# ----------------------------------------
# Trian losses: [-0.89687, -0.99912, -1.04047, -0.8905, -0.99923, -1.01054, 0.1326, -0.71413, -0.02102, -0.67291]
# AVG train loss: -0.71122
# Train S_nmad: 0.07399	Train out_rate: 0.13434
# ----------------------------------------
# Test losses: [-0.66269, -0.99613, -1.0087, -0.86528, -1.00569, -1.02393, 0.09529, -0.69505, -0.04995, -0.70377]
# AVG test loss: -0.69159
# Test S_nmad: 0.07224	Test out_rate: 0.13348
# ----------------------------------------
# Time: 59.919
# ========================================
# EPOCH #22/100:
# ----------------------------------------
# Trian losses: [-0.9526, -1.06673, -1.02277, -0.92154, -1.00639, -1.04418, 0.0996, -0.73615, -0.04255, -0.71527]
# AVG train loss: -0.74086
# Train S_nmad: 0.07151	Train out_rate: 0.13027
# ----------------------------------------
# Test losses: [-0.72797, -0.99893, -1.00588, -0.90508, -0.96518, -1.02917, 0.06249, -0.72028, -0.07126, -0.71664]
# AVG test loss: -0.70779
# Test S_nmad: 0.07092	Test out_rate: 0.12939
# ----------------------------------------
# Time: 60.473
# ========================================
# EPOCH #23/100:
# ----------------------------------------
# Trian losses: [-1.02131, -1.11642, -1.04886, -0.94706, -1.01449, -1.10906, 0.06693, -0.74475, -0.06365, -0.75405]
# AVG train loss: -0.77527
# Train S_nmad: 0.07014	Train out_rate: 0.12727
# ----------------------------------------
# Test losses: [-0.78526, -0.9777, -0.97828, -0.95787, -1.01322, -1.02268, 0.03035, -0.75457, -0.09216, -0.74618]
# AVG test loss: -0.72976
# Test S_nmad: 0.0715	Test out_rate: 0.12582
# ----------------------------------------
# Time: 58.259
# ========================================
# EPOCH #24/100:
# ----------------------------------------
# Trian losses: [-1.07039, -1.12332, -1.07896, -0.9341, -1.0229, -1.12657, 0.0347, -0.74719, -0.08434, -0.79323]
# AVG train loss: -0.79463
# Train S_nmad: 0.06811	Train out_rate: 0.12431
# ----------------------------------------
# Test losses: [-0.88274, -0.99587, -1.02571, -0.9521, -0.94718, -1.02704, -0.00095, -0.78481, -0.11267, -0.69642]
# AVG test loss: -0.74255
# Test S_nmad: 0.06972	Test out_rate: 0.12518
# ----------------------------------------
# Time: 59.902
# ========================================
# EPOCH #25/100:
# ----------------------------------------
# Trian losses: [-1.01679, -1.08003, -1.07071, -0.97912, -1.03908, -1.12576, 0.00307, -0.75322, -0.10463, -0.79763]
# AVG train loss: -0.79639
# Train S_nmad: 0.06621	Train out_rate: 0.12121
# ----------------------------------------
# Test losses: [-0.86435, -1.0689, -1.01078, -0.97841, -0.92464, -1.09521, -0.03144, -0.76039, -0.13279, -0.80436]
# AVG test loss: -0.76713
# Test S_nmad: 0.06724	Test out_rate: 0.12129
# ----------------------------------------
# Time: 59.97
# ========================================
# EPOCH #26/100:
# ----------------------------------------
# Trian losses: [-1.01932, -1.11669, -1.06038, -1.01005, -1.02605, -1.13378, -0.02787, -0.77151, -0.12454, -0.80377]
# AVG train loss: -0.8094
# Train S_nmad: 0.06629	Train out_rate: 0.12142
# ----------------------------------------
# Test losses: [-0.98493, -1.05232, -0.99524, -0.99261, -0.86348, -1.05327, -0.0612, -0.80783, -0.1525, -0.77446]
# AVG test loss: -0.77378
# Test S_nmad: 0.06756	Test out_rate: 0.12192
# ----------------------------------------
# Time: 59.458
# ========================================
# EPOCH #27/100:
# ----------------------------------------
# Trian losses: [-1.04199, -1.12354, -1.09063, -1.03075, -0.9936, -1.15903, -0.05813, -0.78323, -0.14406, -0.82637]
# AVG train loss: -0.82513
# Train S_nmad: 0.06483	Train out_rate: 0.11895
# ----------------------------------------
# Test losses: [-1.00187, -1.12946, -0.9378, -1.00721, -0.85327, -1.07404, -0.09029, -0.78215, -0.17181, -0.8194]
# AVG test loss: -0.78673
# Test S_nmad: 0.0674	Test out_rate: 0.12112
# ----------------------------------------
# Time: 60.523
# ========================================
# EPOCH #28/100:
# ----------------------------------------
# Trian losses: [-1.06086, -1.1496, -1.09498, -0.96224, -1.03238, -1.14538, -0.08772, -0.81676, -0.1632, -0.84969]
# AVG train loss: -0.83628
# Train S_nmad: 0.06461	Train out_rate: 0.11759
# ----------------------------------------
# Test losses: [-1.01758, -1.14647, -1.08383, -0.79582, -0.96056, -1.10081, -0.11873, -0.82372, -0.19071, -0.79549]
# AVG test loss: -0.80337
# Test S_nmad: 0.06348	Test out_rate: 0.11558
# ----------------------------------------
# Time: 59.665
# ========================================
# EPOCH #29/100:
# ----------------------------------------
# Trian losses: [-1.08982, -1.17639, -1.12057, -0.99907, -1.08169, -1.12408, -0.11661, -0.84197, -0.18196, -0.8345]
# AVG train loss: -0.85667
# Train S_nmad: 0.06298	Train out_rate: 0.1158
# ----------------------------------------
# Test losses: [-1.07828, -1.16265, -0.90875, -0.98975, -1.09448, -1.04357, -0.14649, -0.81104, -0.2092, -0.85436]
# AVG test loss: -0.82986
# Test S_nmad: 0.06081	Test out_rate: 0.11266
# ----------------------------------------
# Time: 60.845
# ========================================
# EPOCH #30/100:
# ----------------------------------------
# Trian losses: [-1.07064, -1.17385, -1.07198, -1.02394, -1.12381, -1.06477, -0.14473, -0.85701, -0.20032, -0.83259]
# AVG train loss: -0.85637
# Train S_nmad: 0.06328	Train out_rate: 0.11462
# ----------------------------------------
# Test losses: [-1.03988, -1.08956, -1.04738, -1.04556, -0.82173, -0.78242, -0.17349, -0.85882, -0.22726, -0.88457]
# AVG test loss: -0.79707
# Test S_nmad: 0.05968	Test out_rate: 0.11434
# ----------------------------------------
# Time: 60.769
# ========================================
# EPOCH #31/100:
# ----------------------------------------
# Trian losses: [-1.11579, -1.10259, -1.08857, -1.03601, -0.9412, -1.13608, -0.17202, -0.88528, -0.21828, -0.87186]
# AVG train loss: -0.85677
# Train S_nmad: 0.06092	Train out_rate: 0.11226
# ----------------------------------------
# Test losses: [-1.05492, -1.15078, -1.08213, -1.04264, -0.72483, -1.08677, -0.19971, -0.87398, -0.24489, -0.82488]
# AVG test loss: -0.82855
# Test S_nmad: 0.0624	Test out_rate: 0.11405
# ----------------------------------------
# Time: 59.48
# ========================================
# EPOCH #32/100:
# ----------------------------------------
# Trian losses: [-1.1589, -1.10401, -1.11035, -1.05963, -0.991, -1.15759, -0.19845, -0.887, -0.23583, -0.92743]
# AVG train loss: -0.88302
# Train S_nmad: 0.06195	Train out_rate: 0.11304
# ----------------------------------------
# Test losses: [-1.15114, -1.07968, -1.09285, -1.07702, -0.86417, -1.20323, -0.22515, -0.89403, -0.26209, -0.90013]
# AVG test loss: -0.87495
# Test S_nmad: 0.05925	Test out_rate: 0.11181
# ----------------------------------------
# Time: 59.799
# ========================================
# EPOCH #33/100:
# ----------------------------------------
# Trian losses: [-1.14753, -1.16113, -1.1582, -1.07365, -1.04955, -1.21736, -0.22398, -0.88639, -0.25298, -0.96164]
# AVG train loss: -0.91324
# Train S_nmad: 0.05919	Train out_rate: 0.10991
# ----------------------------------------
# Test losses: [-1.13834, -1.1516, -1.06055, -1.07377, -0.85042, -1.22066, -0.24966, -0.90725, -0.27886, -0.93753]
# AVG test loss: -0.88686
# Test S_nmad: 0.05865	Test out_rate: 0.1086
# ----------------------------------------
# Time: 61.497
# ========================================
# EPOCH #34/100:
# ----------------------------------------
# Trian losses: [-1.15275, -1.18223, -1.16425, -1.10129, -1.08155, -1.25618, -0.24857, -0.89811, -0.26973, -0.96545]
# AVG train loss: -0.93201
# Train S_nmad: 0.05834	Train out_rate: 0.10872
# ----------------------------------------
# Test losses: [-1.11402, -1.13043, -1.14185, -1.08726, -1.03602, -1.15417, -0.27306, -0.88543, -0.29522, -0.95333]
# AVG test loss: -0.90708
# Test S_nmad: 0.05839	Test out_rate: 0.10738
# ----------------------------------------
# Time: 59.165
# ========================================
# EPOCH #35/100:
# ----------------------------------------
# Trian losses: [-1.17094, -1.17663, -1.20233, -1.07869, -1.13101, -1.23814, -0.2722, -0.90921, -0.28608, -0.94707]
# AVG train loss: -0.94123
# Train S_nmad: 0.05807	Train out_rate: 0.10856
# ----------------------------------------
# Test losses: [-1.06265, -1.13498, -1.18756, -1.08591, -1.09327, -1.2106, -0.29529, -0.85591, -0.31117, -0.96811]
# AVG test loss: -0.92054
# Test S_nmad: 0.05714	Test out_rate: 0.1062
# ----------------------------------------
# Time: 60.979
# ========================================
# EPOCH #36/100:
# ----------------------------------------
# Trian losses: [-1.12448, -1.2199, -1.20164, -1.0958, -1.13818, -1.22387, -0.29489, -0.92192, -0.30205, -0.9795]
# AVG train loss: -0.95022
# Train S_nmad: 0.05769	Train out_rate: 0.1072
# ----------------------------------------
# Test losses: [-1.16045, -1.14229, -1.21398, -1.10266, -1.12325, -1.213, -0.31655, -0.89601, -0.32671, -0.93314]
# AVG test loss: -0.9428
# Test S_nmad: 0.05622	Test out_rate: 0.10475
# ----------------------------------------
# Time: 61.226
# ========================================
# EPOCH #37/100:
# ----------------------------------------
# Trian losses: [-1.14733, -1.2277, -1.24227, -1.10746, -1.12898, -1.25526, -0.31669, -0.93273, -0.31762, -0.99699]
# AVG train loss: -0.9673
# Train S_nmad: 0.05648	Train out_rate: 0.10586
# ----------------------------------------
# Test losses: [-1.06213, -1.20259, -1.22281, -1.13777, -1.07255, -1.18355, -0.33717, -0.91665, -0.34187, -0.99653]
# AVG test loss: -0.94736
# Test S_nmad: 0.0565	Test out_rate: 0.10543
# ----------------------------------------
# Time: 60.782
# ========================================
# EPOCH #38/100:
# ----------------------------------------
# Trian losses: [-1.19736, -1.22826, -1.23385, -1.12693, -1.14552, -1.18016, -0.33764, -0.9309, -0.33283, -1.02456]
# AVG train loss: -0.9738
# Train S_nmad: 0.05619	Train out_rate: 0.1047
# ----------------------------------------
# Test losses: [-1.1482, -1.1993, -1.21949, -1.1487, -1.01076, -1.03172, -0.35728, -0.89352, -0.35669, -1.01477]
# AVG test loss: -0.93804
# Test S_nmad: 0.05687	Test out_rate: 0.10347
# ----------------------------------------
# Time: 60.807
# ========================================
# EPOCH #39/100:
# ----------------------------------------
# Trian losses: [-1.2186, -1.25421, -1.17245, -1.13619, -1.14793, -1.1715, -0.35775, -0.92076, -0.34766, -1.04964]
# AVG train loss: -0.97767
# Train S_nmad: 0.05671	Train out_rate: 0.10391
# ----------------------------------------
# Test losses: [-1.09903, -1.14165, -1.03925, -1.14723, -1.05519, -1.05641, -0.37682, -0.85647, -0.37114, -1.05187]
# AVG test loss: -0.91951
# Test S_nmad: 0.05634	Test out_rate: 0.104
# ----------------------------------------
# Time: 62.929
# ========================================
# EPOCH #40/100:
# ----------------------------------------
# Trian losses: [-1.04273, -1.17753, -1.16513, -1.13391, -1.10338, -1.18291, -0.37703, -0.89901, -0.36213, -1.06859]
# AVG train loss: -0.95123
# Train S_nmad: 0.05763	Train out_rate: 0.10357
# ----------------------------------------
# Test losses: [-0.81641, -1.08388, -1.13535, -1.05322, -1.08312, -1.08895, -0.39567, -0.83831, -0.38527, -1.07205]
# AVG test loss: -0.89522
# Test S_nmad: 0.05838	Test out_rate: 0.10486
# ----------------------------------------
# Time: 60.691
# ========================================
# EPOCH #41/100:
# ----------------------------------------
# Trian losses: [-1.0625, -1.20753, -1.1244, -0.96306, -1.10603, -1.17934, -0.3955, -0.87022, -0.37625, -1.09293]
# AVG train loss: -0.93778
# Train S_nmad: 0.05734	Train out_rate: 0.10414
# ----------------------------------------
# Test losses: [-0.96687, -1.13114, -1.11947, -0.8972, -0.96114, -1.11522, -0.41374, -0.89738, -0.39903, -1.08213]
# AVG test loss: -0.89833
# Test S_nmad: 0.05722	Test out_rate: 0.10471
# ----------------------------------------
# Time: 60.562
# ========================================
# EPOCH #42/100:
# ----------------------------------------
# Trian losses: [-1.08162, -1.21266, -1.14917, -0.98785, -1.10718, -1.22559, -0.41321, -0.92006, -0.38999, -1.10681]
# AVG train loss: -0.95941
# Train S_nmad: 0.05555	Train out_rate: 0.10173
# ----------------------------------------
# Test losses: [-1.0285, -1.15117, -1.11477, -1.00941, -0.97346, -1.15457, -0.4311, -0.94119, -0.41247, -1.03014]
# AVG test loss: -0.92468
# Test S_nmad: 0.05628	Test out_rate: 0.10351
# ----------------------------------------
# Time: 59.231
# ========================================
# EPOCH #43/100:
# ----------------------------------------
# Trian losses: [-1.14537, -1.22098, -1.17592, -1.00594, -1.17031, -1.2754, -0.43018, -0.91997, -0.40339, -1.04592]
# AVG train loss: -0.97934
# Train S_nmad: 0.05618	Train out_rate: 0.10143
# ----------------------------------------
# Test losses: [-1.11016, -1.15662, -1.21378, -1.02518, -1.07702, -1.20547, -0.44779, -0.96678, -0.42554, -0.99599]
# AVG test loss: -0.96243
# Test S_nmad: 0.05517	Test out_rate: 0.10212
# ----------------------------------------
# Time: 59.653
# ========================================
# EPOCH #44/100:
# ----------------------------------------
# Trian losses: [-1.1797, -1.25795, -1.19804, -1.03541, -1.19292, -1.26721, -0.44645, -0.94145, -0.41641, -1.04669]
# AVG train loss: -0.99822
# Train S_nmad: 0.05535	Train out_rate: 0.10043
# ----------------------------------------
# Test losses: [-1.05373, -1.17599, -1.17387, -1.06533, -1.13462, -1.08914, -0.46382, -0.96863, -0.43824, -1.04892]
# AVG test loss: -0.96123
# Test S_nmad: 0.05519	Test out_rate: 0.10218
# ----------------------------------------
# Time: 67.225
# ========================================
# EPOCH #45/100:
# ----------------------------------------
# Trian losses: [-1.2129, -1.24245, -1.22759, -1.09818, -1.18563, -1.21337, -0.46204, -0.96941, -0.42909, -1.06262]
# AVG train loss: -1.01033
# Train S_nmad: 0.05481	Train out_rate: 0.10014
# ----------------------------------------
# Test losses: [-1.10396, -1.17843, -1.14359, -1.10036, -1.11815, -1.07067, -0.47918, -0.99489, -0.45056, -1.01119]
# AVG test loss: -0.9651
# Test S_nmad: 0.05374	Test out_rate: 0.1009
# ----------------------------------------
# Time: 58.187
# ========================================
# EPOCH #46/100:
# ----------------------------------------
# Trian losses: [-1.25016, -1.26275, -1.26508, -1.14927, -1.18998, -1.26014, -0.47699, -0.99599, -0.4414, -1.06608]
# AVG train loss: -1.03578
# Train S_nmad: 0.0531	Train out_rate: 0.09887
# ----------------------------------------
# Test losses: [-1.17044, -1.19036, -1.17777, -1.05801, -0.96821, -1.10921, -0.49392, -1.00252, -0.46251, -1.02452]
# AVG test loss: -0.96575
# Test S_nmad: 0.05311	Test out_rate: 0.09995
# ----------------------------------------
# Time: 60.731
# ========================================
# EPOCH #47/100:
# ----------------------------------------
# Trian losses: [-1.25668, -1.23405, -1.27463, -1.18529, -1.19272, -1.27655, -0.49131, -1.01602, -0.45335, -1.0919]
# AVG train loss: -1.04725
# Train S_nmad: 0.05274	Train out_rate: 0.09777
# ----------------------------------------
# Test losses: [-1.1509, -1.12991, -1.21581, -1.17664, -0.92467, -1.1872, -0.50814, -1.02152, -0.47418, -1.05535]
# AVG test loss: -0.98443
# Test S_nmad: 0.05241	Test out_rate: 0.09986
# ----------------------------------------
# Time: 60.093
# ========================================
# EPOCH #48/100:
# ----------------------------------------
# Trian losses: [-1.2589, -1.22232, -1.27787, -1.20589, -1.08501, -1.27681, -0.50505, -1.03517, -0.46497, -1.05166]
# AVG train loss: -1.03836
# Train S_nmad: 0.05271	Train out_rate: 0.09728
# ----------------------------------------
# Test losses: [-1.12145, -1.1546, -1.25281, -1.1913, -0.98745, -1.14845, -0.5217, -1.03761, -0.48558, -1.05898]
# AVG test loss: -0.99599
# Test S_nmad: 0.05164	Test out_rate: 0.09701
# ----------------------------------------
# Time: 58.681
# ========================================
# EPOCH #49/100:
# ----------------------------------------
# Trian losses: [-1.21932, -1.14384, -1.2592, -1.22509, -1.05951, -1.29951, -0.51824, -1.04181, -0.47626, -1.04399]
# AVG train loss: -1.02868
# Train S_nmad: 0.05284	Train out_rate: 0.09721
# ----------------------------------------
# Test losses: [-1.09107, -1.06961, -1.11647, -1.22682, -1.08121, -1.21379, -0.53462, -1.05106, -0.49665, -1.08629]
# AVG test loss: -0.99676
# Test S_nmad: 0.05103	Test out_rate: 0.09659
# ----------------------------------------
# Time: 60.514
# ========================================
# EPOCH #50/100:
# ----------------------------------------
# Trian losses: [-1.20326, -1.08681, -1.23993, -1.22082, -1.10696, -1.30648, -0.53089, -1.05799, -0.48722, -1.01652]
# AVG train loss: -1.02569
# Train S_nmad: 0.05393	Train out_rate: 0.09765
# ----------------------------------------
# Test losses: [-1.08814, -1.06796, -1.2001, -1.23995, -1.0885, -1.2269, -0.54703, -1.01546, -0.5074, -0.98918]
# AVG test loss: -0.99706
# Test S_nmad: 0.05182	Test out_rate: 0.09777
# ----------------------------------------
# Time: 60.469
# ========================================
# EPOCH #51/100:
# ----------------------------------------
# Trian losses: [-1.19997, -1.14619, -1.22976, -1.21495, -1.11953, -1.23115, -0.54306, -1.04, -0.49788, -1.01686]
# AVG train loss: -1.02393
# Train S_nmad: 0.05182	Train out_rate: 0.09627
# ----------------------------------------
# Test losses: [-1.15927, -1.11308, -1.09785, -1.22437, -1.0628, -1.0342, -0.55901, -1.02005, -0.51786, -1.00681]
# AVG test loss: -0.97953
# Test S_nmad: 0.05222	Test out_rate: 0.09922
# ----------------------------------------
# Time: 58.477
# ========================================
# EPOCH #52/100:
# ----------------------------------------
# Trian losses: [-1.21006, -1.18564, -1.18535, -1.21729, -1.09039, -1.1792, -0.55474, -1.05922, -0.50824, -1.07392]
# AVG train loss: -1.0264
# Train S_nmad: 0.05314	Train out_rate: 0.09585
# ----------------------------------------
# Test losses: [-1.1364, -1.10776, -1.17228, -1.18039, -1.11523, -1.13297, -0.57053, -1.06093, -0.52801, -1.08876]
# AVG test loss: -1.00932
# Test S_nmad: 0.05018	Test out_rate: 0.09814
# ----------------------------------------
# Time: 60.103
# ========================================
# EPOCH #53/100:
# ----------------------------------------
# Trian losses: [-1.23915, -1.21084, -1.16583, -1.19105, -1.05625, -1.09499, -0.56597, -1.05089, -0.51833, -1.1438]
# AVG train loss: -1.02371
# Train S_nmad: 0.05299	Train out_rate: 0.09593
# ----------------------------------------
# Test losses: [-1.07448, -1.12966, -1.03348, -1.15839, -1.01242, -0.72366, -0.58163, -1.06373, -0.53793, -1.1267]
# AVG test loss: -0.94421
# Test S_nmad: 0.05149	Test out_rate: 0.09812
# ----------------------------------------
# Time: 60.439
# ========================================
# EPOCH #54/100:
# ----------------------------------------
# Trian losses: [-1.27944, -1.23706, -1.18934, -1.12463, -1.07592, -1.04806, -0.57675, -1.08253, -0.52813, -1.16561]
# AVG train loss: -1.03075
# Train S_nmad: 0.052	Train out_rate: 0.09573
# ----------------------------------------
# Test losses: [-1.16611, -1.11479, -1.12222, -1.10374, -1.07447, -1.07039, -0.59235, -1.05812, -0.54752, -1.14236]
# AVG test loss: -0.99921
# Test S_nmad: 0.05064	Test out_rate: 0.09604
# ----------------------------------------
# Time: 59.548
# ========================================
# EPOCH #55/100:
# ----------------------------------------
# Trian losses: [-1.30597, -1.21433, -1.24918, -1.1429, -1.05353, -1.16135, -0.58706, -1.08962, -0.53762, -1.18167]
# AVG train loss: -1.05232
# Train S_nmad: 0.05081	Train out_rate: 0.09384
# ----------------------------------------
# Test losses: [-1.24277, -1.17453, -1.09827, -1.1503, -1.03761, -1.1045, -0.60258, -1.08406, -0.55679, -1.16817]
# AVG test loss: -1.02196
# Test S_nmad: 0.05048	Test out_rate: 0.09659
# ----------------------------------------
# Time: 60.712
# ========================================
# EPOCH #56/100:
# ----------------------------------------
# Trian losses: [-1.32846, -1.18852, -1.23848, -1.20097, -1.11829, -1.25174, -0.59692, -1.08198, -0.54679, -1.1905]
# AVG train loss: -1.07426
# Train S_nmad: 0.05056	Train out_rate: 0.09428
# ----------------------------------------
# Test losses: [-1.28844, -1.14616, -1.07306, -1.20573, -1.00059, -1.01501, -0.61243, -1.06446, -0.56577, -1.10989]
# AVG test loss: -1.00815
# Test S_nmad: 0.05018	Test out_rate: 0.09697
# ----------------------------------------
# Time: 59.167
# ========================================
# EPOCH #57/100:
# ----------------------------------------
# Trian losses: [-1.35814, -1.22713, -1.27004, -1.23718, -1.14427, -1.30198, -0.60636, -1.07279, -0.55568, -1.17332]
# AVG train loss: -1.09469
# Train S_nmad: 0.05018	Train out_rate: 0.0934
# ----------------------------------------
# Test losses: [-1.24221, -1.07208, -1.05621, -1.20548, -1.08638, -1.17939, -0.62202, -1.07521, -0.57456, -1.09467]
# AVG test loss: -1.02082
# Test S_nmad: 0.04915	Test out_rate: 0.09423
# ----------------------------------------
# Time: 58.917
# ========================================
# EPOCH #58/100:
# ----------------------------------------
# Trian losses: [-1.28267, -1.2595, -1.2562, -1.21825, -1.19227, -1.3204, -0.61539, -1.04905, -0.56431, -1.12292]
# AVG train loss: -1.0881
# Train S_nmad: 0.04975	Train out_rate: 0.09265
# ----------------------------------------
# Test losses: [-1.13455, -1.18737, -1.18153, -1.17975, -1.15273, -1.22158, -0.63121, -1.06602, -0.58314, -1.14277]
# AVG test loss: -1.04806
# Test S_nmad: 0.04859	Test out_rate: 0.09504
# ----------------------------------------
# Time: 69.461
# ========================================
# EPOCH #59/100:
# ----------------------------------------
# Trian losses: [-1.25366, -1.26862, -1.23435, -1.16619, -1.21214, -1.29967, -0.62404, -1.08307, -0.57266, -1.10769]
# AVG train loss: -1.08221
# Train S_nmad: 0.04996	Train out_rate: 0.09226
# ----------------------------------------
# Test losses: [-1.03163, -1.26097, -0.94042, -1.21625, -1.22706, -1.1069, -0.63993, -1.04698, -0.59152, -1.10027]
# AVG test loss: -1.01619
# Test S_nmad: 0.05036	Test out_rate: 0.09568
# ----------------------------------------
# Time: 59.244
# ========================================
# EPOCH #60/100:
# ----------------------------------------
# Trian losses: [-1.26242, -1.26767, -1.1369, -1.1809, -1.25502, -1.30257, -0.6323, -1.10159, -0.58076, -1.15831]
# AVG train loss: -1.08784
# Train S_nmad: 0.04948	Train out_rate: 0.09226
# ----------------------------------------
# Test losses: [-1.15329, -1.23053, -1.13635, -1.14542, -1.2082, -1.23789, -0.6482, -1.0854, -0.5997, -1.15563]
# AVG test loss: -1.06006
# Test S_nmad: 0.04869	Test out_rate: 0.09397
# ----------------------------------------
# Time: 60.249
# ========================================
# EPOCH #61/100:
# ----------------------------------------
# Trian losses: [-1.315, -1.23532, -1.11373, -1.21713, -1.2779, -1.28764, -0.6402, -1.10305, -0.5886, -1.19203]
# AVG train loss: -1.09706
# Train S_nmad: 0.04799	Train out_rate: 0.09143
# ----------------------------------------
# Test losses: [-1.26252, -1.26888, -0.97119, -1.19195, -1.26807, -1.23118, -0.65609, -1.00659, -0.60766, -1.18438]
# AVG test loss: -1.06485
# Test S_nmad: 0.04814	Test out_rate: 0.0952
# ----------------------------------------
# Time: 60.472
# ========================================
# EPOCH #62/100:
# ----------------------------------------
# Trian losses: [-1.32318, -1.30803, -1.16968, -1.23139, -1.30368, -1.31481, -0.64774, -1.08835, -0.59622, -1.16108]
# AVG train loss: -1.11442
# Train S_nmad: 0.04881	Train out_rate: 0.09196
# ----------------------------------------
# Test losses: [-1.26785, -1.25456, -0.95017, -1.20024, -1.22528, -1.24017, -0.6636, -1.06297, -0.61547, -1.14163]
# AVG test loss: -1.06219
# Test S_nmad: 0.04843	Test out_rate: 0.0944
# ----------------------------------------
# Time: 58.388
# ========================================
# EPOCH #63/100:
# ----------------------------------------
# Trian losses: [-1.3198, -1.34478, -1.21329, -1.26988, -1.3073, -1.32071, -0.65494, -1.0751, -0.60358, -1.1677]
# AVG train loss: -1.12771
# Train S_nmad: 0.04847	Train out_rate: 0.09087
# ----------------------------------------
# Test losses: [-1.27007, -1.2332, -1.17082, -1.21434, -1.1854, -1.29657, -0.67073, -1.06344, -0.62306, -1.1682]
# AVG test loss: -1.08958
# Test S_nmad: 0.04726	Test out_rate: 0.09269
# ----------------------------------------
# Time: 60.584
# ========================================
# EPOCH #64/100:
# ----------------------------------------
# Trian losses: [-1.3115, -1.3477, -1.19954, -1.27082, -1.25104, -1.31873, -0.66185, -1.06535, -0.61071, -1.23112]
# AVG train loss: -1.12684
# Train S_nmad: 0.04962	Train out_rate: 0.09084
# ----------------------------------------
# Test losses: [-1.16329, -1.28288, -0.9075, -1.26277, -1.22153, -1.23414, -0.6775, -1.05513, -0.63043, -1.16203]
# AVG test loss: -1.05972
# Test S_nmad: 0.04965	Test out_rate: 0.09204
# ----------------------------------------
# Time: 60.175
# ========================================
# EPOCH #65/100:
# ----------------------------------------
# Trian losses: [-1.33424, -1.38511, -1.19068, -1.25622, -1.24702, -1.32304, -0.6684, -1.08444, -0.6176, -1.23192]
# AVG train loss: -1.13387
# Train S_nmad: 0.0481	Train out_rate: 0.09026
# ----------------------------------------
# Test losses: [-1.23503, -1.19926, -1.17337, -1.27132, -1.13694, -1.04248, -0.68384, -0.98933, -0.63766, -1.16307]
# AVG test loss: -1.05323
# Test S_nmad: 0.04816	Test out_rate: 0.09098
# ----------------------------------------
# Time: 59.139
# ========================================
# EPOCH #66/100:
# ----------------------------------------
# Trian losses: [-1.36005, -1.36098, -1.23016, -1.2535, -1.26083, -1.10654, -0.67463, -1.06982, -0.6243, -1.2228]
# AVG train loss: -1.11636
# Train S_nmad: 0.04913	Train out_rate: 0.09001
# ----------------------------------------
# Test losses: [-1.26257, -1.33308, -1.12424, -1.21999, -1.16643, -0.86844, -0.69004, -1.01745, -0.64467, -1.21257]
# AVG test loss: -1.05395
# Test S_nmad: 0.04719	Test out_rate: 0.09033
# ----------------------------------------
# Time: 60.612
# ========================================
# EPOCH #67/100:
# ----------------------------------------
# Trian losses: [-1.37121, -1.351, -1.24048, -1.26225, -1.28019, -1.14831, -0.68048, -1.08014, -0.63078, -1.2148]
# AVG train loss: -1.12596
# Train S_nmad: 0.0481	Train out_rate: 0.08975
# ----------------------------------------
# Test losses: [-1.33007, -1.30142, -1.1477, -1.23724, -1.1865, -0.76503, -0.69603, -1.05229, -0.65144, -1.23311]
# AVG test loss: -1.06008
# Test S_nmad: 0.04805	Test out_rate: 0.09438
# ----------------------------------------
# Time: 59.794
# ========================================
# EPOCH #68/100:
# ----------------------------------------
# Trian losses: [-1.38072, -1.36926, -1.2201, -1.19561, -1.27561, -1.17253, -0.6859, -1.06282, -0.63706, -1.20368]
# AVG train loss: -1.12033
# Train S_nmad: 0.04766	Train out_rate: 0.08948
# ----------------------------------------
# Test losses: [-1.32086, -1.31927, -1.18529, -1.16293, -1.23097, -1.11412, -0.70188, -1.07074, -0.65799, -1.18684]
# AVG test loss: -1.09509
# Test S_nmad: 0.04648	Test out_rate: 0.09312
# ----------------------------------------
# Time: 60.196
# ========================================
# EPOCH #69/100:
# ----------------------------------------
# Trian losses: [-1.36407, -1.35426, -1.17189, -1.20901, -1.22511, -1.21879, -0.69086, -1.04082, -0.64314, -1.24489]
# AVG train loss: -1.11628
# Train S_nmad: 0.04827	Train out_rate: 0.08967
# ----------------------------------------
# Test losses: [-1.29361, -1.20941, -1.09145, -1.20263, -1.13163, -1.16139, -0.70773, -1.06594, -0.66424, -1.21565]
# AVG test loss: -1.07437
# Test S_nmad: 0.04724	Test out_rate: 0.09036
# ----------------------------------------
# Time: 60.919
# ========================================
# EPOCH #70/100:
# ----------------------------------------
# Trian losses: [-1.29588, -1.34983, -1.16887, -1.20666, -1.1895, -1.29241, -0.69518, -1.04333, -0.64903, -1.23399]
# AVG train loss: -1.11247
# Train S_nmad: 0.04918	Train out_rate: 0.08919
# ----------------------------------------
# Test losses: [-1.20976, -1.26152, -1.1068, -1.20209, -1.14959, -1.10166, -0.71388, -1.00811, -0.6703, -1.22824]
# AVG test loss: -1.06519
# Test S_nmad: 0.04728	Test out_rate: 0.09026
# ----------------------------------------
# Time: 59.368
# ========================================
# EPOCH #71/100:
# ----------------------------------------
# Trian losses: [-1.34044, -1.30797, -1.20106, -1.21701, -1.24972, -1.37084, -0.69865, -1.03852, -0.65472, -1.27187]
# AVG train loss: -1.13508
# Train S_nmad: 0.04766	Train out_rate: 0.08833
# ----------------------------------------
# Test losses: [-1.27348, -1.18087, -1.1653, -1.15478, -1.21845, -1.21433, -0.7206, -1.06633, -0.67611, -1.23053]
# AVG test loss: -1.09008
# Test S_nmad: 0.04665	Test out_rate: 0.09065
# ----------------------------------------
# Time: 61.188
# ========================================
# EPOCH #72/100:
# ----------------------------------------
# Trian losses: [-1.33469, -1.27114, -1.24554, -1.22717, -1.281, -1.37699, -0.70133, -0.96915, -0.66021, -1.28367]
# AVG train loss: -1.13509
# Train S_nmad: 0.04712	Train out_rate: 0.08795
# ----------------------------------------
# Test losses: [-1.29142, -1.12322, -1.19442, -1.16173, -1.25889, -1.3175, -0.72707, -1.03516, -0.68168, -1.22706]
# AVG test loss: -1.10182
# Test S_nmad: 0.04617	Test out_rate: 0.09021
# ----------------------------------------
# Time: 60.658
# ========================================
# EPOCH #73/100:
# ----------------------------------------
# Trian losses: [-1.32099, -1.23498, -1.27227, -1.266, -1.36617, -1.34809, -0.70367, -0.95094, -0.66554, -1.24733]
# AVG train loss: -1.1376
# Train S_nmad: 0.04809	Train out_rate: 0.08854
# ----------------------------------------
# Test losses: [-1.22227, -1.20691, -1.08462, -1.20406, -1.26045, -1.29994, -0.72988, -1.00044, -0.68708, -1.23482]
# AVG test loss: -1.09305
# Test S_nmad: 0.04681	Test out_rate: 0.09048
# ----------------------------------------
# Time: 67.37
# ========================================
# EPOCH #74/100:
# ----------------------------------------
# Trian losses: [-1.2725, -1.23727, -1.30463, -1.24905, -1.38582, -1.39037, -0.70722, -1.03077, -0.6707, -1.24959]
# AVG train loss: -1.14979
# Train S_nmad: 0.04698	Train out_rate: 0.08788
# ----------------------------------------
# Test losses: [-1.28425, -1.11144, -1.1587, -1.02174, -1.04403, -1.36364, -0.72656, -1.0062, -0.69229, -1.24081]
# AVG test loss: -1.06497
# Test S_nmad: 0.04739	Test out_rate: 0.0904
# ----------------------------------------
# Time: 60.738
# ========================================
# EPOCH #75/100:
# ----------------------------------------
# Trian losses: [-1.22054, -1.31223, -1.31732, -1.16894, -1.36425, -1.42588, -0.71321, -1.06012, -0.67567, -1.25111]
# AVG train loss: -1.15092
# Train S_nmad: 0.04665	Train out_rate: 0.08796
# ----------------------------------------
# Test losses: [-1.09803, -1.24797, -1.23954, -1.20529, -1.2353, -1.36192, -0.7242, -1.05106, -0.69738, -1.23747]
# AVG test loss: -1.10982
# Test S_nmad: 0.04635	Test out_rate: 0.0894
# ----------------------------------------
# Time: 60.766
# ========================================
# EPOCH #76/100:
# ----------------------------------------
# Trian losses: [-1.22101, -1.35031, -1.22881, -1.18035, -1.33996, -1.45448, -0.72091, -1.07793, -0.68047, -1.23211]
# AVG train loss: -1.14863
# Train S_nmad: 0.04753	Train out_rate: 0.0876
# ----------------------------------------
# Test losses: [-1.11728, -1.26833, -1.21285, -1.0887, -1.27555, -1.34919, -0.73034, -1.0891, -0.70234, -1.17414]
# AVG test loss: -1.10078
# Test S_nmad: 0.04741	Test out_rate: 0.09126
# ----------------------------------------
# Time: 58.842
# ========================================
# EPOCH #77/100:
# ----------------------------------------
# Trian losses: [-1.19819, -1.38841, -1.16179, -1.20881, -1.31967, -1.408, -0.72866, -1.07891, -0.68515, -1.24753]
# AVG train loss: -1.14251
# Train S_nmad: 0.04798	Train out_rate: 0.08786
# ----------------------------------------
# Test losses: [-0.96031, -1.1922, -1.10077, -1.23256, -1.23051, -1.36488, -0.73788, -1.11165, -0.70717, -1.14977]
# AVG test loss: -1.07877
# Test S_nmad: 0.04646	Test out_rate: 0.09177
# ----------------------------------------
# Time: 60.856
# ========================================
# EPOCH #78/100:
# ----------------------------------------
# Trian losses: [-1.20372, -1.37669, -1.14642, -1.25556, -1.31496, -1.44229, -0.73436, -1.11518, -0.68969, -1.25221]
# AVG train loss: -1.15311
# Train S_nmad: 0.04816	Train out_rate: 0.0872
# ----------------------------------------
# Test losses: [-1.03961, -1.30779, -1.0857, -1.21282, -1.26115, -1.33505, -0.74356, -1.11125, -0.71188, -1.17495]
# AVG test loss: -1.09838
# Test S_nmad: 0.0458	Test out_rate: 0.09064
# ----------------------------------------
# Time: 59.438
# ========================================
# EPOCH #79/100:
# ----------------------------------------
# Trian losses: [-1.28465, -1.34685, -1.21549, -1.28296, -1.34253, -1.45852, -0.73701, -1.15065, -0.69414, -1.28119]
# AVG train loss: -1.1794
# Train S_nmad: 0.04606	Train out_rate: 0.08721
# ----------------------------------------
# Test losses: [-1.15986, -1.30163, -1.18318, -1.25254, -1.31576, -1.30594, -0.75177, -1.14742, -0.71636, -1.2524]
# AVG test loss: -1.13869
# Test S_nmad: 0.04506	Test out_rate: 0.08858
# ----------------------------------------
# Time: 59.414
# ========================================
# EPOCH #80/100:
# ----------------------------------------
# Trian losses: [-1.36149, -1.32686, -1.29655, -1.30194, -1.33739, -1.44897, -0.73727, -1.17546, -0.6986, -1.31698]
# AVG train loss: -1.20015
# Train S_nmad: 0.04533	Train out_rate: 0.08629
# ----------------------------------------
# Test losses: [-1.17881, -1.29329, -1.20354, -1.26361, -1.35695, -1.22888, -0.76018, -1.16619, -0.72063, -1.12092]
# AVG test loss: -1.1293
# Test S_nmad: 0.0444	Test out_rate: 0.08856
# ----------------------------------------
# Time: 60.165
# ========================================
# EPOCH #81/100:
# ----------------------------------------
# Trian losses: [-1.40231, -1.34343, -1.35012, -1.25844, -1.30524, -1.38313, -0.73817, -1.19106, -0.7031, -1.20442]
# AVG train loss: -1.18794
# Train S_nmad: 0.04608	Train out_rate: 0.08621
# ----------------------------------------
# Test losses: [-1.20376, -1.32431, -1.24701, -1.15945, -1.22409, -1.32014, -0.76019, -1.0808, -0.72468, -1.14775]
# AVG test loss: -1.11922
# Test S_nmad: 0.04596	Test out_rate: 0.08919
# ----------------------------------------
# Time: 59.189
# ========================================
# EPOCH #82/100:
# ----------------------------------------
# Trian losses: [-1.40657, -1.34066, -1.37823, -1.30972, -1.31862, -1.28337, -0.74428, -1.16091, -0.70769, -1.23748]
# AVG train loss: -1.18875
# Train S_nmad: 0.0452	Train out_rate: 0.08532
# ----------------------------------------
# Test losses: [-1.24685, -1.34129, -1.31359, -1.22909, -1.30937, -1.1339, -0.75768, -1.16578, -0.72851, -1.20308]
# AVG test loss: -1.14292
# Test S_nmad: 0.0465	Test out_rate: 0.08709
# ----------------------------------------
# Time: 61.051
# ========================================
# EPOCH #83/100:
# ----------------------------------------
# Trian losses: [-1.39982, -1.39686, -1.37447, -1.30706, -1.36881, -1.3276, -0.75477, -1.15388, -0.71233, -1.26129]
# AVG train loss: -1.20569
# Train S_nmad: 0.04543	Train out_rate: 0.08527
# ----------------------------------------
# Test losses: [-1.35725, -1.15606, -1.17575, -1.24343, -1.34988, -1.23127, -0.77058, -1.16595, -0.73226, -1.16534]
# AVG test loss: -1.13478
# Test S_nmad: 0.04518	Test out_rate: 0.09056
# ----------------------------------------
# Time: 60.666
# ========================================
# EPOCH #84/100:
# ----------------------------------------
# Trian losses: [-1.41535, -1.38087, -1.41373, -1.32884, -1.41245, -1.29301, -0.76443, -1.1455, -0.71702, -1.30115]
# AVG train loss: -1.21723
# Train S_nmad: 0.04593	Train out_rate: 0.08502
# ----------------------------------------
# Test losses: [-1.33728, -1.15606, -1.36146, -1.30577, -1.31907, -1.28039, -0.78091, -1.14498, -0.73603, -1.21124]
# AVG test loss: -1.16332
# Test S_nmad: 0.04516	Test out_rate: 0.08824
# ----------------------------------------
# Time: 58.413
# ========================================
# EPOCH #85/100:
# ----------------------------------------
# Trian losses: [-1.37775, -1.37021, -1.44121, -1.33994, -1.44397, -1.26939, -0.76991, -1.15088, -0.72161, -1.32359]
# AVG train loss: -1.22085
# Train S_nmad: 0.04642	Train out_rate: 0.08498
# ----------------------------------------
# Test losses: [-1.35402, -1.22521, -1.39475, -1.30925, -1.39055, -1.12771, -0.78489, -1.16077, -0.73983, -1.23141]
# AVG test loss: -1.17184
# Test S_nmad: 0.04407	Test out_rate: 0.08636
# ----------------------------------------
# Time: 61.205
# ========================================
# EPOCH #86/100:
# ----------------------------------------
# Trian losses: [-1.33419, -1.34492, -1.46533, -1.33896, -1.4306, -1.28966, -0.7741, -1.16029, -0.72607, -1.33374]
# AVG train loss: -1.21979
# Train S_nmad: 0.04591	Train out_rate: 0.085
# ----------------------------------------
# Test losses: [-1.38168, -1.32331, -1.38946, -1.24076, -1.35845, -1.03616, -0.7894, -1.1541, -0.74367, -1.27239]
# AVG test loss: -1.16894
# Test S_nmad: 0.04402	Test out_rate: 0.08779
# ----------------------------------------
# Time: 61.269
# ========================================
# EPOCH #87/100:
# ----------------------------------------
# Trian losses: [-1.30103, -1.32065, -1.3657, -1.34461, -1.42747, -1.33874, -0.77837, -1.18265, -0.7304, -1.34234]
# AVG train loss: -1.2132
# Train S_nmad: 0.04548	Train out_rate: 0.08442
# ----------------------------------------
# Test losses: [-1.15437, -1.2071, -1.17991, -1.23875, -1.32272, -1.29764, -0.79396, -1.15671, -0.74752, -1.27673]
# AVG test loss: -1.13754
# Test S_nmad: 0.04624	Test out_rate: 0.08747
# ----------------------------------------
# Time: 62.103
# ========================================
# EPOCH #88/100:
# ----------------------------------------
# Trian losses: [-1.27061, -1.29314, -1.39698, -1.29765, -1.36531, -1.40027, -0.78243, -1.20788, -0.73456, -1.34216]
# AVG train loss: -1.2091
# Train S_nmad: 0.04491	Train out_rate: 0.08401
# ----------------------------------------
# Test losses: [-1.10446, -1.10552, -1.31901, -1.2347, -1.27091, -1.35727, -0.79756, -1.16539, -0.7513, -1.30913]
# AVG test loss: -1.14153
# Test S_nmad: 0.04522	Test out_rate: 0.08867
# ----------------------------------------
# Time: 63.328
# ========================================
# EPOCH #89/100:
# ----------------------------------------
# Trian losses: [-1.32948, -1.30084, -1.42115, -1.31266, -1.40129, -1.42791, -0.78617, -1.22933, -0.73856, -1.34589]
# AVG train loss: -1.22933
# Train S_nmad: 0.04402	Train out_rate: 0.08363
# ----------------------------------------
# Test losses: [-1.13543, -0.92679, -1.29572, -1.16971, -1.35587, -1.377, -0.80024, -1.17428, -0.75501, -1.33595]
# AVG test loss: -1.1326
# Test S_nmad: 0.04563	Test out_rate: 0.0879
# ----------------------------------------
# Time: 62.496
# ========================================
# EPOCH #90/100:
# ----------------------------------------
# Trian losses: [-1.38814, -1.3532, -1.44445, -1.3042, -1.38713, -1.46649, -0.78998, -1.22513, -0.74244, -1.34092]
# AVG train loss: -1.24421
# Train S_nmad: 0.04364	Train out_rate: 0.08342
# ----------------------------------------
# Test losses: [-1.19953, -1.27043, -1.35609, -1.30319, -1.315, -1.37917, -0.80272, -1.18056, -0.75867, -1.28837]
# AVG test loss: -1.18537
# Test S_nmad: 0.04506	Test out_rate: 0.08681
# ----------------------------------------
# Time: 60.392
# ========================================
# EPOCH #91/100:
# ----------------------------------------
# Trian losses: [-1.38485, -1.3994, -1.47949, -1.26792, -1.38738, -1.48316, -0.79393, -1.21588, -0.74627, -1.28258]
# AVG train loss: -1.24409
# Train S_nmad: 0.04345	Train out_rate: 0.08334
# ----------------------------------------
# Test losses: [-1.15124, -1.19521, -1.3709, -1.21964, -1.29433, -1.40498, -0.80553, -1.18205, -0.76237, -1.24604]
# AVG test loss: -1.16323
# Test S_nmad: 0.0449	Test out_rate: 0.08623
# ----------------------------------------
# Time: 63.826
# ========================================
# EPOCH #92/100:
# ----------------------------------------
# Trian losses: [-1.37524, -1.46574, -1.4692, -1.30599, -1.38585, -1.48383, -0.79807, -1.18687, -0.75006, -1.32045]
# AVG train loss: -1.25413
# Train S_nmad: 0.04338	Train out_rate: 0.08316
# ----------------------------------------
# Test losses: [-1.21182, -0.97654, -1.16699, -1.26965, -1.23796, -1.39706, -0.80932, -1.16963, -0.76608, -1.28341]
# AVG test loss: -1.12885
# Test S_nmad: 0.04552	Test out_rate: 0.08688
# ----------------------------------------
# Time: 61.478
# ========================================
# EPOCH #93/100:
# ----------------------------------------
# Trian losses: [-1.35887, -1.35044, -0.8756, -1.32201, -1.37348, -1.46592, -0.80232, -1.16955, -0.75381, -1.31504]
# AVG train loss: -1.1787
# Train S_nmad: 0.04688	Train out_rate: 0.08418
# ----------------------------------------
# Test losses: [-1.27322, -1.14277, -0.33326, -1.18505, -1.22355, -1.36896, -0.81374, -1.1512, -0.76977, -1.18027]
# AVG test loss: -1.04418
# Test S_nmad: 0.05353	Test out_rate: 0.09098
# ----------------------------------------
# Time: 59.194
# ========================================
# EPOCH #94/100:
# ----------------------------------------
# Trian losses: [-1.34792, -1.35851, -1.09696, -1.32655, -1.37317, -1.41903, -0.80643, -1.17568, -0.75753, -1.31054]
# AVG train loss: -1.19723
# Train S_nmad: 0.04924	Train out_rate: 0.09097
# ----------------------------------------
# Test losses: [-1.27906, -1.28879, -0.71946, -1.24723, -1.19496, -1.34375, -0.81827, -1.12656, -0.77338, -1.26272]
# AVG test loss: -1.10542
# Test S_nmad: 0.05043	Test out_rate: 0.09372
# ----------------------------------------
# Time: 63.707
# ========================================
# EPOCH #95/100:
# ----------------------------------------
# Trian losses: [-1.33502, -1.39365, -1.10616, -1.32128, -1.34912, -1.42262, -0.81045, -1.20816, -0.7612, -1.31887]
# AVG train loss: -1.20265
# Train S_nmad: 0.0488	Train out_rate: 0.09288
# ----------------------------------------
# Test losses: [-1.23633, -1.26807, -0.93456, -1.20077, -1.2976, -1.38899, -0.82261, -1.16736, -0.77697, -1.29542]
# AVG test loss: -1.13887
# Test S_nmad: 0.04922	Test out_rate: 0.09326
# ----------------------------------------
# Time: 62.118
# ========================================
# EPOCH #96/100:
# ----------------------------------------
# Trian losses: [-1.28144, -1.40269, -1.15041, -1.28473, -1.33839, -1.42584, -0.81444, -1.19526, -0.76479, -1.34077]
# AVG train loss: -1.19988
# Train S_nmad: 0.04846	Train out_rate: 0.09203
# ----------------------------------------
# Test losses: [-1.07136, -1.26013, -1.06093, -1.22708, -1.30079, -1.31379, -0.82677, -1.08175, -0.78048, -1.31329]
# AVG test loss: -1.12364
# Test S_nmad: 0.04854	Test out_rate: 0.08777
# ----------------------------------------
# Time: 61.908
# ========================================
# EPOCH #97/100:
# ----------------------------------------
# Trian losses: [-1.28251, -1.42803, -1.20843, -1.19461, -1.31924, -1.45459, -0.81838, -1.19877, -0.76833, -1.32476]
# AVG train loss: -1.19977
# Train S_nmad: 0.04744	Train out_rate: 0.08784
# ----------------------------------------
# Test losses: [-1.21875, -1.30447, -1.11785, -1.13971, -1.29186, -1.39346, -0.83066, -1.12303, -0.78392, -1.28771]
# AVG test loss: -1.14914
# Test S_nmad: 0.04776	Test out_rate: 0.08619
# ----------------------------------------
# Time: 61.312
# ========================================
# EPOCH #98/100:
# ----------------------------------------
# Trian losses: [-1.31582, -1.45634, -1.26996, -1.14414, -1.34399, -1.49008, -0.82224, -1.15526, -0.77185, -1.32527]
# AVG train loss: -1.20949
# Train S_nmad: 0.04554	Train out_rate: 0.08331
# ----------------------------------------
# Test losses: [-1.30195, -1.35922, -1.11382, -0.99953, -1.19849, -1.38344, -0.83438, -1.09597, -0.78732, -1.26487]
# AVG test loss: -1.1339
# Test S_nmad: 0.04703	Test out_rate: 0.08713
# ----------------------------------------
# Time: 59.836
# ========================================
# EPOCH #99/100:
# ----------------------------------------
# Trian losses: [-1.32629, -1.47897, -1.32034, -1.19544, -1.34317, -1.50164, -0.82606, -1.15183, -0.7753, -1.3131]
# AVG train loss: -1.22321
# Train S_nmad: 0.04587	Train out_rate: 0.08299
# ----------------------------------------
# Test losses: [-1.13979, -1.37586, -1.19978, -1.12631, -1.08473, -1.38351, -0.83803, -1.17477, -0.79064, -1.21502]
# AVG test loss: -1.13284
# Test S_nmad: 0.04553	Test out_rate: 0.08668
# ----------------------------------------
# Time: 63.469
# ========================================
# EPOCH #100/100:
# ----------------------------------------
# Trian losses: [-1.40059, -1.47923, -1.34382, -1.23274, -1.36798, -1.50576, -0.82976, -1.12058, -0.77866, -1.3212]
# AVG train loss: -1.23803
# Train S_nmad: 0.04379	Train out_rate: 0.08241
# ----------------------------------------
# Test losses: [-1.12584, -1.3961, -1.24476, -1.20321, -1.35786, -1.39404, -0.84149, -1.15611, -0.79394, -1.3218]
# AVG test loss: -1.18351
# Test S_nmad: 0.04391	Test out_rate: 0.08565
# ----------------------------------------
# Time: 64.286
# ========================================

# %%
ens.fit(
    X_train=X_01, 
    y_train=y_01,
    X_test=X_02,
    y_test=y_02,
    epochs=100, 
    batch_size=2**15,
    shuffle=True,
    optimizer=optimizer, 
    optimizer_args={'lr': 0.0001, 'weight_decay': 0.001},
    verbose=True,
    metrics={'S_nmad': sigma_nmad, 'out_rate': out_rate}
);
# Out:
# Device: cuda:0
# Test mode: True
# ========================================
# EPOCH #1/100:
# ----------------------------------------
# Trian losses: [-1.43063, -1.47719, -1.3695, -1.29533, -1.46697, -1.53173, -0.76006, -1.18248, -0.7615, -1.37595]
# AVG train loss: -1.26513
# Train S_nmad: 0.04472	Train out_rate: 0.08231
# ----------------------------------------
# Test losses: [-1.40292, -1.42794, -1.32529, -1.24755, -1.39773, -1.44264, -0.79209, -1.16209, -0.78449, -1.34903]
# AVG test loss: -1.23318
# Test S_nmad: 0.04365	Test out_rate: 0.08296
# ----------------------------------------
# Time: 61.648
# ========================================
# EPOCH #2/100:
# ----------------------------------------
# Trian losses: [-1.44808, -1.43097, -1.32364, -1.3333, -1.43693, -1.4711, -0.81301, -1.18966, -0.80611, -1.38726]
# AVG train loss: -1.264
# Train S_nmad: 0.04386	Train out_rate: 0.0814
# ----------------------------------------
# Test losses: [-1.37924, -1.40868, -1.31851, -1.33984, -1.35343, -1.43212, -0.81844, -1.17757, -0.79847, -1.31533]
# AVG test loss: -1.23416
# Test S_nmad: 0.04169	Test out_rate: 0.08284
# ----------------------------------------
# Time: 61.87
# ========================================
# EPOCH #3/100:
# ----------------------------------------
# Trian losses: [-1.43252, -1.46621, -1.32553, -1.36623, -1.35648, -1.46088, -0.84089, -1.18883, -0.83861, -1.35202]
# AVG train loss: -1.26282
# Train S_nmad: 0.04328	Train out_rate: 0.08105
# ----------------------------------------
# Test losses: [-1.41283, -1.43045, -1.33774, -1.3587, -1.37691, -1.43504, -0.83957, -1.20116, -0.80776, -1.32074]
# AVG test loss: -1.25209
# Test S_nmad: 0.04164	Test out_rate: 0.08249
# ----------------------------------------
# Time: 64.277
# ========================================
# EPOCH #4/100:
# ----------------------------------------
# Trian losses: [-1.49855, -1.51178, -1.39136, -1.3704, -1.45979, -1.51449, -0.86166, -1.2056, -0.86059, -1.36769]
# AVG train loss: -1.30419
# Train S_nmad: 0.04168	Train out_rate: 0.08043
# ----------------------------------------
# Test losses: [-1.41958, -1.44382, -1.3632, -1.36706, -1.42152, -1.45072, -0.86557, -1.21623, -0.83887, -1.34977]
# AVG test loss: -1.27363
# Test S_nmad: 0.04081	Test out_rate: 0.08128
# ----------------------------------------
# Time: 62.718
# ========================================
# EPOCH #5/100:
# ----------------------------------------
# Trian losses: [-1.50612, -1.51898, -1.4141, -1.39968, -1.46993, -1.54202, -0.87389, -1.24343, -0.87873, -1.40487]
# AVG train loss: -1.32517
# Train S_nmad: 0.04136	Train out_rate: 0.08012
# ----------------------------------------
# Test losses: [-1.43704, -1.44786, -1.38201, -1.38009, -1.43226, -1.46286, -0.86254, -1.23195, -0.85965, -1.37036]
# AVG test loss: -1.28666
# Test S_nmad: 0.04068	Test out_rate: 0.08125
# ----------------------------------------
# Time: 63.894
# ========================================
# EPOCH #6/100:
# ----------------------------------------
# Trian losses: [-1.52366, -1.53312, -1.42201, -1.42654, -1.49931, -1.55172, -0.88569, -1.26876, -0.90082, -1.41459]
# AVG train loss: -1.34262
# Train S_nmad: 0.04102	Train out_rate: 0.08001
# ----------------------------------------
# Test losses: [-1.44113, -1.45914, -1.40007, -1.37677, -1.4422, -1.4675, -0.89048, -1.24371, -0.8815, -1.3712]
# AVG test loss: -1.29737
# Test S_nmad: 0.04027	Test out_rate: 0.08124
# ----------------------------------------
# Time: 63.128
# ========================================
# EPOCH #7/100:
# ----------------------------------------
# Trian losses: [-1.51594, -1.54426, -1.43528, -1.41995, -1.50203, -1.56338, -0.89749, -1.27952, -0.91907, -1.40315]
# AVG train loss: -1.34801
# Train S_nmad: 0.04086	Train out_rate: 0.07968
# ----------------------------------------
# Test losses: [-1.44732, -1.46363, -1.40144, -1.37171, -1.45706, -1.47377, -0.90757, -1.25194, -0.90234, -1.32651]
# AVG test loss: -1.30033
# Test S_nmad: 0.04015	Test out_rate: 0.08107
# ----------------------------------------
# Time: 61.254
# ========================================
# EPOCH #8/100:
# ----------------------------------------
# Trian losses: [-1.50907, -1.54629, -1.44279, -1.41539, -1.5051, -1.57383, -0.90702, -1.28842, -0.93381, -1.39495]
# AVG train loss: -1.35167
# Train S_nmad: 0.04065	Train out_rate: 0.0796
# ----------------------------------------
# Test losses: [-1.46818, -1.4577, -1.39917, -1.38253, -1.46181, -1.4653, -0.91725, -1.24575, -0.91543, -1.34232]
# AVG test loss: -1.30554
# Test S_nmad: 0.03993	Test out_rate: 0.08062
# ----------------------------------------
# Time: 63.677
# ========================================
# EPOCH #9/100:
# ----------------------------------------
# Trian losses: [-1.50089, -1.54251, -1.44555, -1.41527, -1.50753, -1.57334, -0.92669, -1.29626, -0.94161, -1.39622]
# AVG train loss: -1.35459
# Train S_nmad: 0.04026	Train out_rate: 0.07926
# ----------------------------------------
# Test losses: [-1.4528, -1.45743, -1.3981, -1.37415, -1.46422, -1.46162, -0.92998, -1.2648, -0.93388, -1.37364]
# AVG test loss: -1.31106
# Test S_nmad: 0.03983	Test out_rate: 0.08005
# ----------------------------------------
# Time: 62.273
# ========================================
# EPOCH #10/100:
# ----------------------------------------
# Trian losses: [-1.51523, -1.53971, -1.449, -1.40634, -1.51167, -1.57175, -0.94584, -1.31131, -0.95175, -1.40472]
# AVG train loss: -1.36073
# Train S_nmad: 0.04034	Train out_rate: 0.07906
# ----------------------------------------
# Test losses: [-1.4542, -1.46367, -1.40098, -1.3764, -1.46662, -1.45663, -0.94865, -1.2626, -0.95029, -1.36311]
# AVG test loss: -1.31432
# Test S_nmad: 0.03957	Test out_rate: 0.07981
# ----------------------------------------
# Time: 60.627
# ========================================
# EPOCH #11/100:
# ----------------------------------------
# Trian losses: [-1.53227, -1.53798, -1.45308, -1.40634, -1.52038, -1.56991, -0.9588, -1.31951, -0.97045, -1.4196]
# AVG train loss: -1.36883
# Train S_nmad: 0.0401	Train out_rate: 0.07885
# ----------------------------------------
# Test losses: [-1.46121, -1.46968, -1.41221, -1.33318, -1.46931, -1.45789, -0.96008, -1.26978, -0.96218, -1.37469]
# AVG test loss: -1.31702
# Test S_nmad: 0.0396	Test out_rate: 0.07975
# ----------------------------------------
# Time: 65.205
# ========================================
# EPOCH #12/100:
# ----------------------------------------
# Trian losses: [-1.53853, -1.54737, -1.45466, -1.418, -1.52698, -1.56485, -0.96836, -1.31909, -0.97909, -1.43923]
# AVG train loss: -1.37561
# Train S_nmad: 0.04063	Train out_rate: 0.07865
# ----------------------------------------
# Test losses: [-1.46356, -1.46756, -1.42639, -1.35727, -1.47038, -1.46487, -0.97054, -1.27893, -0.97628, -1.38489]
# AVG test loss: -1.32607
# Test S_nmad: 0.03937	Test out_rate: 0.07973
# ----------------------------------------
# Time: 60.531
# ========================================
# EPOCH #13/100:
# ----------------------------------------
# Trian losses: [-1.5449, -1.56367, -1.45949, -1.44544, -1.52843, -1.54854, -0.97473, -1.32309, -0.9942, -1.443]
# AVG train loss: -1.38255
# Train S_nmad: 0.0401	Train out_rate: 0.07836
# ----------------------------------------
# Test losses: [-1.46221, -1.47128, -1.42908, -1.39205, -1.4675, -1.47761, -0.97929, -1.27855, -0.98329, -1.38608]
# AVG test loss: -1.33269
# Test S_nmad: 0.03928	Test out_rate: 0.07949
# ----------------------------------------
# Time: 61.182
# ========================================
# EPOCH #14/100:
# ----------------------------------------
# Trian losses: [-1.55278, -1.57232, -1.47273, -1.4486, -1.52672, -1.54202, -0.98395, -1.32584, -1.00471, -1.43395]
# AVG train loss: -1.38636
# Train S_nmad: 0.0397	Train out_rate: 0.07819
# ----------------------------------------
# Test losses: [-1.46278, -1.47249, -1.42962, -1.39674, -1.4634, -1.44967, -0.98538, -1.2699, -0.98969, -1.38022]
# AVG test loss: -1.32999
# Test S_nmad: 0.03913	Test out_rate: 0.0794
# ----------------------------------------
# Time: 60.901
# ========================================
# EPOCH #15/100:
# ----------------------------------------
# Trian losses: [-1.56035, -1.56522, -1.48575, -1.44943, -1.52403, -1.55411, -0.99101, -1.31948, -1.01411, -1.43625]
# AVG train loss: -1.38998
# Train S_nmad: 0.03929	Train out_rate: 0.07803
# ----------------------------------------
# Test losses: [-1.46305, -1.47153, -1.43412, -1.39947, -1.46494, -1.46302, -0.99214, -1.26784, -1.00681, -1.37752]
# AVG test loss: -1.33405
# Test S_nmad: 0.03887	Test out_rate: 0.07899
# ----------------------------------------
# Time: 60.25
# ========================================
# EPOCH #16/100:
# ----------------------------------------
# Trian losses: [-1.5675, -1.55737, -1.49055, -1.43777, -1.51637, -1.57821, -0.99887, -1.31113, -1.02339, -1.44274]
# AVG train loss: -1.39239
# Train S_nmad: 0.03899	Train out_rate: 0.0779
# ----------------------------------------
# Test losses: [-1.4656, -1.46729, -1.44043, -1.4021, -1.47527, -1.4782, -0.99608, -1.2615, -1.01729, -1.38754]
# AVG test loss: -1.33913
# Test S_nmad: 0.03876	Test out_rate: 0.07874
# ----------------------------------------
# Time: 61.122
# ========================================
# EPOCH #17/100:
# ----------------------------------------
# Trian losses: [-1.56985, -1.55122, -1.49249, -1.42184, -1.51499, -1.58281, -1.00066, -1.32278, -1.03124, -1.43384]
# AVG train loss: -1.39217
# Train S_nmad: 0.03895	Train out_rate: 0.07779
# ----------------------------------------
# Test losses: [-1.4613, -1.45254, -1.43941, -1.38616, -1.45919, -1.47022, -0.99277, -1.25222, -1.01993, -1.39668]
# AVG test loss: -1.33304
# Test S_nmad: 0.03886	Test out_rate: 0.07884
# ----------------------------------------
# Time: 64.14
# ========================================
# EPOCH #18/100:
# ----------------------------------------
# Trian losses: [-1.56653, -1.54039, -1.48748, -1.42252, -1.52503, -1.58531, -0.98772, -1.30136, -1.03699, -1.40555]
# AVG train loss: -1.38589
# Train S_nmad: 0.03907	Train out_rate: 0.07778
# ----------------------------------------
# Test losses: [-1.45374, -1.43688, -1.4459, -1.34823, -1.47151, -1.46206, -0.97259, -1.24833, -1.02032, -1.39006]
# AVG test loss: -1.32496
# Test S_nmad: 0.03919	Test out_rate: 0.07887
# ----------------------------------------
# Time: 61.532
# ========================================
# EPOCH #19/100:
# ----------------------------------------
# Trian losses: [-1.56215, -1.511, -1.47947, -1.43661, -1.54053, -1.58523, -0.95827, -1.25619, -1.03841, -1.39126]
# AVG train loss: -1.37591
# Train S_nmad: 0.03924	Train out_rate: 0.0776
# ----------------------------------------
# Test losses: [-1.44381, -1.46194, -1.44273, -1.36004, -1.46998, -1.4548, -0.98014, -1.25797, -1.03932, -1.32692]
# AVG test loss: -1.32377
# Test S_nmad: 0.03907	Test out_rate: 0.07919
# ----------------------------------------
# Time: 64.754
# ========================================
# EPOCH #20/100:
# ----------------------------------------
# Trian losses: [-1.5565, -1.51751, -1.48837, -1.46142, -1.54311, -1.58721, -0.94214, -1.22963, -1.04679, -1.39952]
# AVG train loss: -1.37722
# Train S_nmad: 0.03962	Train out_rate: 0.07738
# ----------------------------------------
# Test losses: [-1.43722, -1.4271, -1.44266, -1.39727, -1.47052, -1.4677, -0.93462, -1.17993, -1.0275, -1.37335]
# AVG test loss: -1.31579
# Test S_nmad: 0.03956	Test out_rate: 0.07865
# ----------------------------------------
# Time: 64.258
# ========================================
# EPOCH #21/100:
# ----------------------------------------
# Trian losses: [-1.54404, -1.53405, -1.49928, -1.46234, -1.54176, -1.58982, -0.93019, -1.23612, -1.05232, -1.43892]
# AVG train loss: -1.38288
# Train S_nmad: 0.03937	Train out_rate: 0.07727
# ----------------------------------------
# Test losses: [-1.43592, -1.45562, -1.44146, -1.40416, -1.46966, -1.47488, -0.94968, -1.20744, -1.03926, -1.37544]
# AVG test loss: -1.32535
# Test S_nmad: 0.03903	Test out_rate: 0.07862
# ----------------------------------------
# Time: 58.992
# ========================================
# EPOCH #22/100:
# ----------------------------------------
# Trian losses: [-1.49868, -1.54951, -1.49734, -1.46992, -1.53908, -1.594, -0.95888, -1.25653, -1.06563, -1.44574]
# AVG train loss: -1.38753
# Train S_nmad: 0.0403	Train out_rate: 0.07716
# ----------------------------------------
# Test losses: [-1.46097, -1.46131, -1.44588, -1.39772, -1.47579, -1.46943, -0.9722, -1.23291, -1.05409, -1.3747]
# AVG test loss: -1.3345
# Test S_nmad: 0.03878	Test out_rate: 0.07894
# ----------------------------------------
# Time: 63.158
# ========================================
# EPOCH #23/100:
# ----------------------------------------
# Trian losses: [-1.47323, -1.54347, -1.50492, -1.45878, -1.53969, -1.59868, -0.99472, -1.29325, -1.07246, -1.44774]
# AVG train loss: -1.39269
# Train S_nmad: 0.03867	Train out_rate: 0.077
# ----------------------------------------
# Test losses: [-1.40759, -1.46668, -1.45213, -1.42155, -1.47983, -1.46321, -0.99957, -1.26158, -1.05596, -1.38639]
# AVG test loss: -1.33945
# Test S_nmad: 0.03846	Test out_rate: 0.07862
# ----------------------------------------
# Time: 63.126
# ========================================
# EPOCH #24/100:
# ----------------------------------------
# Trian losses: [-1.50123, -1.53001, -1.50033, -1.43523, -1.54824, -1.59208, -1.01927, -1.32637, -1.07592, -1.45751]
# AVG train loss: -1.39862
# Train S_nmad: 0.03871	Train out_rate: 0.07684
# ----------------------------------------
# Test losses: [-1.433, -1.45075, -1.4499, -1.38469, -1.47951, -1.46061, -1.02064, -1.2798, -1.05337, -1.39366]
# AVG test loss: -1.34059
# Test S_nmad: 0.03843	Test out_rate: 0.07788
# ----------------------------------------
# Time: 60.113
# ========================================
# EPOCH #25/100:
# ----------------------------------------
# Trian losses: [-1.5342, -1.5286, -1.48122, -1.42902, -1.55988, -1.56342, -1.0424, -1.33823, -1.06793, -1.46946]
# AVG train loss: -1.40144
# Train S_nmad: 0.03865	Train out_rate: 0.07675
# ----------------------------------------
# Test losses: [-1.45338, -1.41807, -1.43469, -1.39399, -1.47617, -1.45227, -1.03414, -1.28159, -1.06935, -1.39802]
# AVG test loss: -1.34117
# Test S_nmad: 0.03815	Test out_rate: 0.07744
# ----------------------------------------
# Time: 62.968
# ========================================
# EPOCH #26/100:
# ----------------------------------------
# Trian losses: [-1.55021, -1.54231, -1.46842, -1.44878, -1.56529, -1.5298, -1.05078, -1.33815, -1.05262, -1.47792]
# AVG train loss: -1.40243
# Train S_nmad: 0.03893	Train out_rate: 0.07681
# ----------------------------------------
# Test losses: [-1.45856, -1.45068, -1.39452, -1.37093, -1.47147, -1.43269, -1.0532, -1.27768, -1.01324, -1.39706]
# AVG test loss: -1.332
# Test S_nmad: 0.03969	Test out_rate: 0.07751
# ----------------------------------------
# Time: 61.392
# ========================================
# EPOCH #27/100:
# ----------------------------------------
# Trian losses: [-1.55144, -1.56463, -1.44775, -1.46491, -1.56237, -1.5216, -1.06382, -1.33242, -1.06241, -1.48533]
# AVG train loss: -1.40567
# Train S_nmad: 0.03966	Train out_rate: 0.07661
# ----------------------------------------
# Test losses: [-1.44461, -1.45773, -1.42532, -1.39075, -1.46552, -1.45229, -1.06501, -1.28516, -1.05434, -1.39858]
# AVG test loss: -1.34393
# Test S_nmad: 0.03839	Test out_rate: 0.07769
# ----------------------------------------
# Time: 62.619
# ========================================
# EPOCH #28/100:
# ----------------------------------------
# Trian losses: [-1.55641, -1.56941, -1.46281, -1.48151, -1.55328, -1.54568, -1.0753, -1.2985, -1.051, -1.4888]
# AVG train loss: -1.40827
# Train S_nmad: 0.0397	Train out_rate: 0.07635
# ----------------------------------------
# Test losses: [-1.45894, -1.46097, -1.38643, -1.42223, -1.47103, -1.45088, -1.07342, -1.28649, -1.08522, -1.39546]
# AVG test loss: -1.34911
# Test S_nmad: 0.03827	Test out_rate: 0.07738
# ----------------------------------------
# Time: 64.495
# ========================================
# EPOCH #29/100:
# ----------------------------------------
# Trian losses: [-1.56473, -1.57762, -1.4649, -1.48767, -1.5421, -1.58093, -1.08268, -1.27585, -1.0426, -1.48716]
# AVG train loss: -1.41062
# Train S_nmad: 0.03952	Train out_rate: 0.07635
# ----------------------------------------
# Test losses: [-1.46329, -1.46656, -1.43566, -1.41715, -1.46965, -1.46951, -1.07582, -1.23816, -1.02609, -1.39052]
# AVG test loss: -1.34524
# Test S_nmad: 0.03952	Test out_rate: 0.07756
# ----------------------------------------
# Time: 61.457
# ========================================
# EPOCH #30/100:
# ----------------------------------------
# Trian losses: [-1.56978, -1.57954, -1.46236, -1.49312, -1.53836, -1.5953, -1.09239, -1.27071, -1.05122, -1.48497]
# AVG train loss: -1.41378
# Train S_nmad: 0.03951	Train out_rate: 0.07615
# ----------------------------------------
# Test losses: [-1.45778, -1.47226, -1.41947, -1.41862, -1.43952, -1.47823, -1.07964, -1.23775, -1.0571, -1.38759]
# AVG test loss: -1.3448
# Test S_nmad: 0.03854	Test out_rate: 0.07785
# ----------------------------------------
# Time: 64.234
# ========================================
# EPOCH #31/100:
# ----------------------------------------
# Trian losses: [-1.58138, -1.57403, -1.4653, -1.49299, -1.52579, -1.60798, -1.09882, -1.29585, -1.08208, -1.48423]
# AVG train loss: -1.42085
# Train S_nmad: 0.03794	Train out_rate: 0.07608
# ----------------------------------------
# Test losses: [-1.46511, -1.47171, -1.43072, -1.41803, -1.45257, -1.47486, -1.08388, -1.24613, -1.07664, -1.39128]
# AVG test loss: -1.35109
# Test S_nmad: 0.03791	Test out_rate: 0.07778
# ----------------------------------------
# Time: 64.47
# ========================================
# EPOCH #32/100:
# ----------------------------------------
# Trian losses: [-1.59297, -1.56706, -1.49106, -1.47967, -1.52287, -1.61548, -1.10374, -1.31368, -1.10532, -1.47338]
# AVG train loss: -1.42652
# Train S_nmad: 0.0378	Train out_rate: 0.07607
# ----------------------------------------
# Test losses: [-1.46914, -1.46769, -1.44061, -1.41275, -1.46332, -1.47051, -1.08903, -1.27641, -1.09029, -1.39787]
# AVG test loss: -1.35776
# Test S_nmad: 0.03794	Test out_rate: 0.07791
# ----------------------------------------
# Time: 62.007
# ========================================
# EPOCH #33/100:
# ----------------------------------------
# Trian losses: [-1.593, -1.5592, -1.5041, -1.44446, -1.53394, -1.61655, -1.10535, -1.3347, -1.12548, -1.45691]
# AVG train loss: -1.42737
# Train S_nmad: 0.03759	Train out_rate: 0.07601
# ----------------------------------------
# Test losses: [-1.46384, -1.46748, -1.45267, -1.41211, -1.44577, -1.46694, -1.09179, -1.29154, -1.09408, -1.39135]
# AVG test loss: -1.35776
# Test S_nmad: 0.03785	Test out_rate: 0.07732
# ----------------------------------------
# Time: 62.197
# ========================================
# EPOCH #34/100:
# ----------------------------------------
# Trian losses: [-1.58069, -1.55179, -1.52418, -1.42704, -1.55088, -1.61569, -1.1062, -1.3483, -1.13568, -1.46]
# AVG train loss: -1.43005
# Train S_nmad: 0.03756	Train out_rate: 0.07591
# ----------------------------------------
# Test losses: [-1.44766, -1.46155, -1.46337, -1.3732, -1.47366, -1.46274, -1.09207, -1.30307, -1.11326, -1.37591]
# AVG test loss: -1.35665
# Test S_nmad: 0.03762	Test out_rate: 0.0768
# ----------------------------------------
# Time: 64.749
# ========================================
# EPOCH #35/100:
# ----------------------------------------
# Trian losses: [-1.57898, -1.55945, -1.53595, -1.43811, -1.5672, -1.61447, -1.10182, -1.35961, -1.14442, -1.47922]
# AVG train loss: -1.43792
# Train S_nmad: 0.0378	Train out_rate: 0.07577
# ----------------------------------------
# Test losses: [-1.44583, -1.45578, -1.46798, -1.36945, -1.46972, -1.46016, -1.08968, -1.30957, -1.12155, -1.38543]
# AVG test loss: -1.35752
# Test S_nmad: 0.03795	Test out_rate: 0.07663
# ----------------------------------------
# Time: 60.302
# ========================================
# EPOCH #36/100:
# ----------------------------------------
# Trian losses: [-1.58156, -1.55495, -1.53782, -1.45801, -1.57614, -1.61345, -1.09034, -1.36926, -1.14945, -1.49054]
# AVG train loss: -1.44215
# Train S_nmad: 0.0376	Train out_rate: 0.07563
# ----------------------------------------
# Test losses: [-1.46053, -1.47067, -1.46836, -1.39764, -1.47535, -1.45791, -1.094, -1.31509, -1.12516, -1.37645]
# AVG test loss: -1.36412
# Test S_nmad: 0.03761	Test out_rate: 0.07711
# ----------------------------------------
# Time: 61.863
# ========================================
# EPOCH #37/100:
# ----------------------------------------
# Trian losses: [-1.5812, -1.5409, -1.53775, -1.48175, -1.58083, -1.61095, -1.05028, -1.37064, -1.15233, -1.48249]
# AVG train loss: -1.43891
# Train S_nmad: 0.03775	Train out_rate: 0.07549
# ----------------------------------------
# Test losses: [-1.45226, -1.45628, -1.46962, -1.41162, -1.48122, -1.45789, -1.09497, -1.31058, -1.12638, -1.38026]
# AVG test loss: -1.36411
# Test S_nmad: 0.03774	Test out_rate: 0.07725
# ----------------------------------------
# Time: 61.712
# ========================================
# EPOCH #38/100:
# ----------------------------------------
# Trian losses: [-1.57957, -1.5385, -1.54338, -1.48947, -1.58256, -1.60414, -1.01231, -1.3713, -1.15398, -1.48235]
# AVG train loss: -1.43575
# Train S_nmad: 0.03852	Train out_rate: 0.07554
# ----------------------------------------
# Test losses: [-1.45859, -1.44071, -1.46837, -1.42066, -1.48064, -1.45587, -0.98323, -1.31013, -1.1135, -1.38947]
# AVG test loss: -1.35212
# Test S_nmad: 0.03821	Test out_rate: 0.0769
# ----------------------------------------
# Time: 58.96
# ========================================
# EPOCH #39/100:
# ----------------------------------------
# Trian losses: [-1.59946, -1.55602, -1.54805, -1.49958, -1.58516, -1.58907, -1.00512, -1.37428, -1.1512, -1.48118]
# AVG train loss: -1.43891
# Train S_nmad: 0.0384	Train out_rate: 0.07556
# ----------------------------------------
# Test losses: [-1.45914, -1.46102, -1.46749, -1.419, -1.4791, -1.44762, -0.95301, -1.31026, -1.07663, -1.38559]
# AVG test loss: -1.34589
# Test S_nmad: 0.03782	Test out_rate: 0.07616
# ----------------------------------------
# Time: 60.07
# ========================================
# EPOCH #40/100:
# ----------------------------------------
# Trian losses: [-1.59638, -1.5813, -1.55152, -1.50651, -1.58531, -1.54677, -1.03509, -1.37733, -1.13125, -1.47277]
# AVG train loss: -1.43842
# Train S_nmad: 0.03772	Train out_rate: 0.07553
# ----------------------------------------
# Test losses: [-1.44766, -1.46095, -1.46459, -1.42926, -1.47799, -1.47433, -1.03739, -1.31139, -1.08271, -1.38357]
# AVG test loss: -1.35698
# Test S_nmad: 0.03763	Test out_rate: 0.07635
# ----------------------------------------
# Time: 59.449
# ========================================
# EPOCH #41/100:
# ----------------------------------------
# Trian losses: [-1.57591, -1.58839, -1.55302, -1.50446, -1.58261, -1.52634, -1.08378, -1.37709, -1.13048, -1.48372]
# AVG train loss: -1.44058
# Train S_nmad: 0.03732	Train out_rate: 0.07519
# ----------------------------------------
# Test losses: [-1.42754, -1.47223, -1.45877, -1.4245, -1.47334, -1.42294, -1.0786, -1.31537, -1.05346, -1.38354]
# AVG test loss: -1.35103
# Test S_nmad: 0.03762	Test out_rate: 0.07657
# ----------------------------------------
# Time: 59.74
# ========================================
# EPOCH #42/100:
# ----------------------------------------
# Trian losses: [-1.57792, -1.59892, -1.55135, -1.49044, -1.57915, -1.53926, -1.12197, -1.37101, -1.10919, -1.50166]
# AVG train loss: -1.44409
# Train S_nmad: 0.03733	Train out_rate: 0.07508
# ----------------------------------------
# Test losses: [-1.42306, -1.47545, -1.4531, -1.39586, -1.45844, -1.42161, -1.1133, -1.31879, -1.09382, -1.3948]
# AVG test loss: -1.35482
# Test S_nmad: 0.03747	Test out_rate: 0.07662
# ----------------------------------------
# Time: 60.408
# ========================================
# EPOCH #43/100:
# ----------------------------------------
# Trian losses: [-1.54391, -1.60276, -1.54267, -1.47196, -1.5662, -1.56753, -1.13622, -1.35835, -1.06313, -1.49629]
# AVG train loss: -1.4349
# Train S_nmad: 0.03758	Train out_rate: 0.07504
# ----------------------------------------
# Test losses: [-1.44334, -1.4744, -1.45281, -1.3986, -1.43586, -1.45977, -1.12539, -1.31095, -1.06384, -1.39487]
# AVG test loss: -1.35598
# Test S_nmad: 0.03809	Test out_rate: 0.07697
# ----------------------------------------
# Time: 58.307
# ========================================
# EPOCH #44/100:
# ----------------------------------------
# Trian losses: [-1.48632, -1.60041, -1.52217, -1.43896, -1.52392, -1.58411, -1.14049, -1.35284, -1.04059, -1.49247]
# AVG train loss: -1.41823
# Train S_nmad: 0.03828	Train out_rate: 0.07515
# ----------------------------------------
# Test losses: [-1.36111, -1.47051, -1.46434, -1.38797, -1.44817, -1.46763, -1.12948, -1.29213, -1.07859, -1.39277]
# AVG test loss: -1.34927
# Test S_nmad: 0.03751	Test out_rate: 0.07651
# ----------------------------------------
# Time: 60.527
# ========================================
# EPOCH #45/100:
# ----------------------------------------
# Trian losses: [-1.48587, -1.60182, -1.48466, -1.45261, -1.47001, -1.59604, -1.15138, -1.3608, -1.09405, -1.49353]
# AVG train loss: -1.41908
# Train S_nmad: 0.0375	Train out_rate: 0.07496
# ----------------------------------------
# Test losses: [-1.40951, -1.46507, -1.42847, -1.38572, -1.43206, -1.44522, -1.13605, -1.30459, -1.08271, -1.39633]
# AVG test loss: -1.34857
# Test S_nmad: 0.03741	Test out_rate: 0.0757
# ----------------------------------------
# Time: 61.776
# ========================================
# EPOCH #46/100:
# ----------------------------------------
# Trian losses: [-1.5211, -1.60687, -1.46933, -1.47647, -1.47495, -1.60917, -1.15332, -1.35963, -1.12011, -1.48864]
# AVG train loss: -1.42796
# Train S_nmad: 0.03785	Train out_rate: 0.07467
# ----------------------------------------
# Test losses: [-1.45118, -1.46586, -1.36036, -1.41339, -1.39291, -1.46272, -1.13866, -1.31799, -1.10875, -1.38568]
# AVG test loss: -1.34975
# Test S_nmad: 0.03722	Test out_rate: 0.07553
# ----------------------------------------
# Time: 60.498
# ========================================
# EPOCH #47/100:
# ----------------------------------------
# Trian losses: [-1.55957, -1.60879, -1.494, -1.49117, -1.52667, -1.62029, -1.16139, -1.34911, -1.10981, -1.47836]
# AVG train loss: -1.43991
# Train S_nmad: 0.03829	Train out_rate: 0.0749
# ----------------------------------------
# Test losses: [-1.46317, -1.47014, -1.41972, -1.42588, -1.4415, -1.46192, -1.1427, -1.29141, -1.12691, -1.37068]
# AVG test loss: -1.3614
# Test S_nmad: 0.0378	Test out_rate: 0.07571
# ----------------------------------------
# Time: 60.591
# ========================================
# EPOCH #48/100:
# ----------------------------------------
# Trian losses: [-1.57732, -1.60314, -1.50506, -1.5117, -1.55695, -1.62299, -1.1629, -1.34611, -1.07061, -1.4801]
# AVG train loss: -1.44369
# Train S_nmad: 0.03859	Train out_rate: 0.07477
# ----------------------------------------
# Test losses: [-1.46721, -1.47622, -1.43703, -1.43487, -1.45811, -1.46615, -1.14527, -1.26512, -1.06949, -1.38768]
# AVG test loss: -1.36071
# Test S_nmad: 0.03742	Test out_rate: 0.07579
# ----------------------------------------
# Time: 61.358
# ========================================
# EPOCH #49/100:
# ----------------------------------------
# Trian losses: [-1.58528, -1.59044, -1.48657, -1.52515, -1.56933, -1.6231, -1.16682, -1.3539, -1.0665, -1.48489]
# AVG train loss: -1.4452
# Train S_nmad: 0.03835	Train out_rate: 0.07456
# ----------------------------------------
# Test losses: [-1.46791, -1.47258, -1.44933, -1.43694, -1.47842, -1.46423, -1.14811, -1.30726, -1.07079, -1.38568]
# AVG test loss: -1.36812
# Test S_nmad: 0.0382	Test out_rate: 0.07561
# ----------------------------------------
# Time: 58.599
# ========================================
# EPOCH #50/100:
# ----------------------------------------
# Trian losses: [-1.58922, -1.5846, -1.47738, -1.53065, -1.57282, -1.62868, -1.16848, -1.35069, -1.11487, -1.48678]
# AVG train loss: -1.45042
# Train S_nmad: 0.03759	Train out_rate: 0.07445
# ----------------------------------------
# Test losses: [-1.46108, -1.43972, -1.42735, -1.43071, -1.47416, -1.46121, -1.14829, -1.29201, -1.11021, -1.39839]
# AVG test loss: -1.36431
# Test S_nmad: 0.03744	Test out_rate: 0.07584
# ----------------------------------------
# Time: 60.147
# ========================================
# EPOCH #51/100:
# ----------------------------------------
# Trian losses: [-1.59582, -1.59189, -1.48722, -1.52334, -1.58376, -1.63464, -1.17139, -1.33066, -1.14694, -1.49226]
# AVG train loss: -1.45579
# Train S_nmad: 0.03727	Train out_rate: 0.07443
# ----------------------------------------
# Test losses: [-1.46527, -1.43797, -1.42292, -1.43226, -1.47615, -1.4659, -1.14823, -1.29032, -1.13563, -1.40518]
# AVG test loss: -1.36798
# Test S_nmad: 0.03732	Test out_rate: 0.07598
# ----------------------------------------
# Time: 60.196
# ========================================
# EPOCH #52/100:
# ----------------------------------------
# Trian losses: [-1.59905, -1.60278, -1.5146, -1.52015, -1.59704, -1.63368, -1.17402, -1.29142, -1.17618, -1.49741]
# AVG train loss: -1.46063
# Train S_nmad: 0.03726	Train out_rate: 0.07439
# ----------------------------------------
# Test losses: [-1.4723, -1.45462, -1.43839, -1.42846, -1.48669, -1.47373, -1.14553, -1.2714, -1.15379, -1.40913]
# AVG test loss: -1.3734
# Test S_nmad: 0.03706	Test out_rate: 0.07598
# ----------------------------------------
# Time: 58.933
# ========================================
# EPOCH #53/100:
# ----------------------------------------
# Trian losses: [-1.5969, -1.59782, -1.53806, -1.5135, -1.60662, -1.62777, -1.17726, -1.27249, -1.19296, -1.50282]
# AVG train loss: -1.46262
# Train S_nmad: 0.03741	Train out_rate: 0.07451
# ----------------------------------------
# Test losses: [-1.46797, -1.45075, -1.45861, -1.42081, -1.48804, -1.47701, -1.14203, -1.23468, -1.15303, -1.39875]
# AVG test loss: -1.36917
# Test S_nmad: 0.03725	Test out_rate: 0.0757
# ----------------------------------------
# Time: 60.782
# ========================================
# EPOCH #54/100:
# ----------------------------------------
# Trian losses: [-1.59621, -1.5974, -1.55433, -1.48895, -1.60768, -1.61656, -1.17915, -1.29906, -1.19534, -1.50727]
# AVG train loss: -1.46419
# Train S_nmad: 0.03737	Train out_rate: 0.07448
# ----------------------------------------
# Test losses: [-1.45447, -1.45291, -1.476, -1.43218, -1.47897, -1.46729, -1.14052, -1.26426, -1.16365, -1.3955]
# AVG test loss: -1.37257
# Test S_nmad: 0.03726	Test out_rate: 0.07539
# ----------------------------------------
# Time: 59.989
# ========================================
# EPOCH #55/100:
# ----------------------------------------
# Trian losses: [-1.60508, -1.60943, -1.55747, -1.45106, -1.60717, -1.61123, -1.17959, -1.33415, -1.20618, -1.52011]
# AVG train loss: -1.46815
# Train S_nmad: 0.037	Train out_rate: 0.07442
# ----------------------------------------
# Test losses: [-1.45614, -1.47099, -1.47408, -1.36588, -1.46745, -1.44834, -1.14214, -1.2901, -1.1726, -1.39063]
# AVG test loss: -1.36784
# Test S_nmad: 0.03691	Test out_rate: 0.07524
# ----------------------------------------
# Time: 59.558
# ========================================
# EPOCH #56/100:
# ----------------------------------------
# Trian losses: [-1.61246, -1.61353, -1.55399, -1.44638, -1.60415, -1.60878, -1.17667, -1.36628, -1.21348, -1.52557]
# AVG train loss: -1.47213
# Train S_nmad: 0.03676	Train out_rate: 0.07427
# ----------------------------------------
# Test losses: [-1.45993, -1.47556, -1.46879, -1.40153, -1.46672, -1.46193, -1.14331, -1.31244, -1.16635, -1.38693]
# AVG test loss: -1.37435
# Test S_nmad: 0.03703	Test out_rate: 0.07563
# ----------------------------------------
# Time: 60.902
# ========================================
# EPOCH #57/100:
# ----------------------------------------
# Trian losses: [-1.60295, -1.60802, -1.55905, -1.47845, -1.6006, -1.59832, -1.16862, -1.38929, -1.21198, -1.51732]
# AVG train loss: -1.47346
# Train S_nmad: 0.03671	Train out_rate: 0.07425
# ----------------------------------------
# Test losses: [-1.45385, -1.46655, -1.46441, -1.38766, -1.47404, -1.46656, -1.14708, -1.33243, -1.15699, -1.39204]
# AVG test loss: -1.37416
# Test S_nmad: 0.0368	Test out_rate: 0.07569
# ----------------------------------------
# Time: 60.346
# ========================================
# EPOCH #58/100:
# ----------------------------------------
# Trian losses: [-1.59068, -1.61132, -1.56662, -1.49501, -1.59217, -1.58676, -1.14661, -1.39796, -1.20547, -1.50672]
# AVG train loss: -1.46993
# Train S_nmad: 0.03681	Train out_rate: 0.07412
# ----------------------------------------
# Test losses: [-1.42919, -1.44798, -1.46671, -1.41152, -1.48012, -1.43018, -1.1627, -1.32222, -1.16248, -1.3931]
# AVG test loss: -1.37062
# Test S_nmad: 0.03683	Test out_rate: 0.07581
# ----------------------------------------
# Time: 60.247
# ========================================
# EPOCH #59/100:
# ----------------------------------------
# Trian losses: [-1.59092, -1.61956, -1.57257, -1.50917, -1.58402, -1.59516, -1.10316, -1.40125, -1.18383, -1.50008]
# AVG train loss: -1.46597
# Train S_nmad: 0.03682	Train out_rate: 0.07401
# ----------------------------------------
# Test losses: [-1.4342, -1.44852, -1.47014, -1.43515, -1.462, -1.46762, -1.13043, -1.32789, -1.17118, -1.39663]
# AVG test loss: -1.37438
# Test S_nmad: 0.0373	Test out_rate: 0.07563
# ----------------------------------------
# Time: 61.242
# ========================================
# EPOCH #60/100:
# ----------------------------------------
# Trian losses: [-1.59084, -1.61733, -1.56539, -1.50931, -1.58996, -1.60879, -1.07991, -1.40094, -1.15368, -1.4986]
# AVG train loss: -1.46148
# Train S_nmad: 0.03687	Train out_rate: 0.07386
# ----------------------------------------
# Test losses: [-1.4454, -1.45406, -1.4756, -1.43469, -1.45117, -1.43119, -1.05541, -1.312, -1.15464, -1.41295]
# AVG test loss: -1.36271
# Test S_nmad: 0.03703	Test out_rate: 0.07534
# ----------------------------------------
# Time: 58.361
# ========================================
# EPOCH #61/100:
# ----------------------------------------
# Trian losses: [-1.57282, -1.59763, -1.54574, -1.50995, -1.58985, -1.58806, -1.0937, -1.40813, -1.15284, -1.49215]
# AVG train loss: -1.45509
# Train S_nmad: 0.03706	Train out_rate: 0.07384
# ----------------------------------------
# Test losses: [-1.44086, -1.45653, -1.46902, -1.42027, -1.46658, -1.48188, -1.09403, -1.32225, -1.13241, -1.39773]
# AVG test loss: -1.36816
# Test S_nmad: 0.03718	Test out_rate: 0.07478
# ----------------------------------------
# Time: 60.811
# ========================================
# EPOCH #62/100:
# ----------------------------------------
# Trian losses: [-1.52083, -1.58735, -1.53154, -1.51977, -1.56344, -1.56366, -1.13268, -1.4047, -1.18273, -1.49124]
# AVG train loss: -1.44979
# Train S_nmad: 0.03715	Train out_rate: 0.07391
# ----------------------------------------
# Test losses: [-1.39781, -1.45727, -1.41525, -1.42251, -1.44411, -1.435, -1.15572, -1.33001, -1.16724, -1.39141]
# AVG test loss: -1.36163
# Test S_nmad: 0.03673	Test out_rate: 0.07437
# ----------------------------------------
# Time: 60.748
# ========================================
# EPOCH #63/100:
# ----------------------------------------
# Trian losses: [-1.51726, -1.60086, -1.53429, -1.5366, -1.5274, -1.57643, -1.15286, -1.4023, -1.19387, -1.51219]
# AVG train loss: -1.45541
# Train S_nmad: 0.03663	Train out_rate: 0.07363
# ----------------------------------------
# Test losses: [-1.38569, -1.46977, -1.40905, -1.43235, -1.46005, -1.46953, -1.16894, -1.33313, -1.18208, -1.39236]
# AVG test loss: -1.37029
# Test S_nmad: 0.03666	Test out_rate: 0.0748
# ----------------------------------------
# Time: 58.875
# ========================================
# EPOCH #64/100:
# ----------------------------------------
# Trian losses: [-1.53907, -1.61158, -1.54416, -1.52497, -1.49915, -1.60207, -1.17436, -1.39384, -1.22271, -1.51958]
# AVG train loss: -1.46315
# Train S_nmad: 0.03686	Train out_rate: 0.07358
# ----------------------------------------
# Test losses: [-1.45163, -1.48002, -1.45505, -1.44214, -1.41531, -1.47801, -1.17643, -1.33067, -1.20137, -1.37478]
# AVG test loss: -1.38054
# Test S_nmad: 0.03668	Test out_rate: 0.07518
# ----------------------------------------
# Time: 61.103
# ========================================
# EPOCH #65/100:
# ----------------------------------------
# Trian losses: [-1.56368, -1.61646, -1.54169, -1.50617, -1.50935, -1.61404, -1.19422, -1.39758, -1.22285, -1.51937]
# AVG train loss: -1.46854
# Train S_nmad: 0.0364	Train out_rate: 0.07364
# ----------------------------------------
# Test losses: [-1.44195, -1.46179, -1.44224, -1.41005, -1.45047, -1.4736, -1.17915, -1.32446, -1.20089, -1.39817]
# AVG test loss: -1.37828
# Test S_nmad: 0.03665	Test out_rate: 0.07521
# ----------------------------------------
# Time: 60.993
# ========================================
# EPOCH #66/100:
# ----------------------------------------
# Trian losses: [-1.58272, -1.62214, -1.54782, -1.50574, -1.56531, -1.62886, -1.20517, -1.40911, -1.23038, -1.51622]
# AVG train loss: -1.48135
# Train S_nmad: 0.03621	Train out_rate: 0.07363
# ----------------------------------------
# Test losses: [-1.45029, -1.44663, -1.44094, -1.38451, -1.46698, -1.46547, -1.17503, -1.33921, -1.20546, -1.40561]
# AVG test loss: -1.37801
# Test S_nmad: 0.03664	Test out_rate: 0.07551
# ----------------------------------------
# Time: 61.518
# ========================================
# EPOCH #67/100:
# ----------------------------------------
# Trian losses: [-1.59473, -1.62987, -1.55045, -1.50231, -1.58279, -1.64177, -1.20429, -1.40184, -1.23123, -1.50985]
# AVG train loss: -1.48491
# Train S_nmad: 0.0362	Train out_rate: 0.07369
# ----------------------------------------
# Test losses: [-1.46764, -1.4502, -1.43404, -1.40686, -1.47622, -1.46918, -1.17702, -1.33118, -1.19865, -1.40158]
# AVG test loss: -1.38126
# Test S_nmad: 0.03663	Test out_rate: 0.07523
# ----------------------------------------
# Time: 60.875
# ========================================
# EPOCH #68/100:
# ----------------------------------------
# Trian losses: [-1.59955, -1.62789, -1.51564, -1.48729, -1.60124, -1.64469, -1.215, -1.37723, -1.23252, -1.49304]
# AVG train loss: -1.47941
# Train S_nmad: 0.03618	Train out_rate: 0.07352
# ----------------------------------------
# Test losses: [-1.46785, -1.46166, -1.46191, -1.414, -1.48345, -1.46478, -1.16233, -1.28837, -1.19683, -1.40167]
# AVG test loss: -1.38029
# Test S_nmad: 0.03669	Test out_rate: 0.07474
# ----------------------------------------
# Time: 60.129
# ========================================
# EPOCH #69/100:
# ----------------------------------------
# Trian losses: [-1.59807, -1.61537, -1.48799, -1.48024, -1.60946, -1.64182, -1.21286, -1.37815, -1.22563, -1.51183]
# AVG train loss: -1.47614
# Train S_nmad: 0.0367	Train out_rate: 0.07339
# ----------------------------------------
# Test losses: [-1.46104, -1.4545, -1.41263, -1.40267, -1.48148, -1.45876, -1.1705, -1.25311, -1.19664, -1.41334]
# AVG test loss: -1.37047
# Test S_nmad: 0.03752	Test out_rate: 0.07433
# ----------------------------------------
# Time: 60.043
# ========================================
# EPOCH #70/100:
# ----------------------------------------
# Trian losses: [-1.60259, -1.61028, -1.4814, -1.4481, -1.61606, -1.64548, -1.20704, -1.36012, -1.21575, -1.52026]
# AVG train loss: -1.47071
# Train S_nmad: 0.03714	Train out_rate: 0.07336
# ----------------------------------------
# Test losses: [-1.46408, -1.44209, -1.41307, -1.40326, -1.47903, -1.45474, -1.17203, -1.32044, -1.20257, -1.41585]
# AVG test loss: -1.37672
# Test S_nmad: 0.0368	Test out_rate: 0.07452
# ----------------------------------------
# Time: 60.701
# ========================================
# EPOCH #71/100:
# ----------------------------------------
# Trian losses: [-1.61266, -1.604, -1.51941, -1.44179, -1.6184, -1.64954, -1.19029, -1.33184, -1.19228, -1.53286]
# AVG train loss: -1.46931
# Train S_nmad: 0.03705	Train out_rate: 0.07324
# ----------------------------------------
# Test losses: [-1.47314, -1.46667, -1.42745, -1.38925, -1.48252, -1.45625, -1.18838, -1.28146, -1.1681, -1.41392]
# AVG test loss: -1.37471
# Test S_nmad: 0.03654	Test out_rate: 0.07468
# ----------------------------------------
# Time: 59.517
# ========================================
# EPOCH #72/100:
# ----------------------------------------
# Trian losses: [-1.6136, -1.61648, -1.54013, -1.46061, -1.61963, -1.65594, -1.16219, -1.32738, -1.17721, -1.52522]
# AVG train loss: -1.46984
# Train S_nmad: 0.03689	Train out_rate: 0.07328
# ----------------------------------------
# Test losses: [-1.46204, -1.47645, -1.44335, -1.40023, -1.48055, -1.46372, -1.14763, -1.2913, -1.14847, -1.4102]
# AVG test loss: -1.37239
# Test S_nmad: 0.03694	Test out_rate: 0.07458
# ----------------------------------------
# Time: 61.186
# ========================================
# EPOCH #73/100:
# ----------------------------------------
# Trian losses: [-1.59319, -1.61289, -1.56109, -1.49381, -1.61932, -1.65716, -1.15519, -1.35485, -1.16455, -1.52842]
# AVG train loss: -1.47405
# Train S_nmad: 0.03712	Train out_rate: 0.07342
# ----------------------------------------
# Test losses: [-1.43926, -1.47103, -1.47728, -1.40694, -1.48181, -1.46907, -1.13406, -1.29546, -1.19176, -1.40604]
# AVG test loss: -1.37727
# Test S_nmad: 0.03668	Test out_rate: 0.07481
# ----------------------------------------
# Time: 61.287
# ========================================
# EPOCH #74/100:
# ----------------------------------------
# Trian losses: [-1.55337, -1.61975, -1.56887, -1.52266, -1.61843, -1.65138, -1.17545, -1.37653, -1.15979, -1.5314]
# AVG train loss: -1.47776
# Train S_nmad: 0.03733	Train out_rate: 0.07322
# ----------------------------------------
# Test losses: [-1.43871, -1.44968, -1.48066, -1.44156, -1.48366, -1.46966, -1.1442, -1.32103, -1.1303, -1.40887]
# AVG test loss: -1.37683
# Test S_nmad: 0.03775	Test out_rate: 0.07472
# ----------------------------------------
# Time: 59.478
# ========================================
# EPOCH #75/100:
# ----------------------------------------
# Trian losses: [-1.53957, -1.63356, -1.56816, -1.53711, -1.61594, -1.64373, -1.18029, -1.39411, -1.14888, -1.52281]
# AVG train loss: -1.47842
# Train S_nmad: 0.03769	Train out_rate: 0.07312
# ----------------------------------------
# Test losses: [-1.4344, -1.44804, -1.47102, -1.44723, -1.47949, -1.4606, -1.14644, -1.3292, -1.16509, -1.39583]
# AVG test loss: -1.37773
# Test S_nmad: 0.03655	Test out_rate: 0.07439
# ----------------------------------------
# Time: 60.599
# ========================================
# EPOCH #76/100:
# ----------------------------------------
# Trian losses: [-1.55472, -1.63233, -1.57694, -1.54539, -1.61744, -1.64071, -1.14085, -1.40277, -1.19462, -1.50806]
# AVG train loss: -1.48138
# Train S_nmad: 0.03698	Train out_rate: 0.07301
# ----------------------------------------
# Test losses: [-1.46551, -1.45628, -1.47298, -1.44187, -1.47298, -1.44263, -1.14212, -1.33743, -1.18152, -1.3749]
# AVG test loss: -1.37882
# Test S_nmad: 0.03701	Test out_rate: 0.07406
# ----------------------------------------
# Time: 61.182
# ========================================
# EPOCH #77/100:
# ----------------------------------------
# Trian losses: [-1.577, -1.62695, -1.58934, -1.53878, -1.62228, -1.63928, -1.15434, -1.4114, -1.21867, -1.50079]
# AVG train loss: -1.48788
# Train S_nmad: 0.03639	Train out_rate: 0.07312
# ----------------------------------------
# Test losses: [-1.45016, -1.46029, -1.47984, -1.44199, -1.47044, -1.43714, -1.13944, -1.34011, -1.19066, -1.40075]
# AVG test loss: -1.38108
# Test S_nmad: 0.03636	Test out_rate: 0.07416
# ----------------------------------------
# Time: 59.847
# ========================================
# EPOCH #78/100:
# ----------------------------------------
# Trian losses: [-1.59992, -1.62129, -1.59976, -1.52706, -1.62239, -1.62505, -1.18243, -1.41431, -1.23693, -1.49781]
# AVG train loss: -1.4927
# Train S_nmad: 0.036	Train out_rate: 0.07304
# ----------------------------------------
# Test losses: [-1.45987, -1.44593, -1.48399, -1.44932, -1.47525, -1.46732, -1.16788, -1.33773, -1.20639, -1.38414]
# AVG test loss: -1.38778
# Test S_nmad: 0.03652	Test out_rate: 0.07422
# ----------------------------------------
# Time: 61.987
# ========================================
# EPOCH #79/100:
# ----------------------------------------
# Trian losses: [-1.62015, -1.6235, -1.60153, -1.50202, -1.60803, -1.59381, -1.21481, -1.41196, -1.24566, -1.50252]
# AVG train loss: -1.4924
# Train S_nmad: 0.03599	Train out_rate: 0.07292
# ----------------------------------------
# Test losses: [-1.47038, -1.43844, -1.48347, -1.42398, -1.4718, -1.44418, -1.18477, -1.33026, -1.20963, -1.40229]
# AVG test loss: -1.38592
# Test S_nmad: 0.03707	Test out_rate: 0.07449
# ----------------------------------------
# Time: 60.865
# ========================================
# EPOCH #80/100:
# ----------------------------------------
# Trian losses: [-1.6342, -1.62571, -1.60001, -1.48939, -1.58343, -1.57155, -1.2341, -1.40381, -1.24286, -1.50262]
# AVG train loss: -1.48877
# Train S_nmad: 0.03657	Train out_rate: 0.0728
# ----------------------------------------
# Test losses: [-1.46386, -1.45627, -1.47953, -1.42249, -1.45175, -1.43328, -1.20638, -1.32179, -1.2082, -1.41853]
# AVG test loss: -1.38621
# Test S_nmad: 0.03675	Test out_rate: 0.07437
# ----------------------------------------
# Time: 60.888
# ========================================
# EPOCH #81/100:
# ----------------------------------------
# Trian losses: [-1.63413, -1.61681, -1.59916, -1.49654, -1.55096, -1.5471, -1.23712, -1.38669, -1.23847, -1.49206]
# AVG train loss: -1.4799
# Train S_nmad: 0.03698	Train out_rate: 0.07279
# ----------------------------------------
# Test losses: [-1.46717, -1.48713, -1.47487, -1.3874, -1.46206, -1.43743, -1.2193, -1.33181, -1.20902, -1.42807]
# AVG test loss: -1.39043
# Test S_nmad: 0.03634	Test out_rate: 0.07411
# ----------------------------------------
# Time: 60.997
# ========================================
# EPOCH #82/100:
# ----------------------------------------
# Trian losses: [-1.63429, -1.62338, -1.60172, -1.50787, -1.51903, -1.54805, -1.23556, -1.362, -1.2365, -1.47957]
# AVG train loss: -1.4748
# Train S_nmad: 0.03753	Train out_rate: 0.07274
# ----------------------------------------
# Test losses: [-1.46281, -1.46953, -1.46845, -1.42388, -1.42967, -1.44835, -1.22146, -1.30291, -1.20705, -1.41493]
# AVG test loss: -1.3849
# Test S_nmad: 0.0362	Test out_rate: 0.07405
# ----------------------------------------
# Time: 59.958
# ========================================
# EPOCH #83/100:
# ----------------------------------------
# Trian losses: [-1.63576, -1.62477, -1.60653, -1.53169, -1.52184, -1.57585, -1.23952, -1.35266, -1.21328, -1.4801]
# AVG train loss: -1.4782
# Train S_nmad: 0.03665	Train out_rate: 0.07254
# ----------------------------------------
# Test losses: [-1.46011, -1.43194, -1.45991, -1.44048, -1.43585, -1.4762, -1.22053, -1.32428, -1.21, -1.40134]
# AVG test loss: -1.38606
# Test S_nmad: 0.03623	Test out_rate: 0.07397
# ----------------------------------------
# Time: 59.714
# ========================================
# EPOCH #84/100:
# ----------------------------------------
# Trian losses: [-1.63766, -1.6367, -1.6063, -1.54115, -1.58536, -1.61094, -1.24584, -1.36523, -1.17783, -1.48679]
# AVG train loss: -1.48938
# Train S_nmad: 0.03629	Train out_rate: 0.07254
# ----------------------------------------
# Test losses: [-1.46427, -1.44295, -1.45603, -1.4407, -1.46909, -1.49396, -1.22539, -1.29219, -1.16446, -1.41032]
# AVG test loss: -1.38594
# Test S_nmad: 0.03611	Test out_rate: 0.0739
# ----------------------------------------
# Time: 60.824
# ========================================
# EPOCH #85/100:
# ----------------------------------------
# Trian losses: [-1.63471, -1.6353, -1.60146, -1.55807, -1.61011, -1.63441, -1.25609, -1.38507, -1.18109, -1.49644]
# AVG train loss: -1.49928
# Train S_nmad: 0.03634	Train out_rate: 0.0725
# ----------------------------------------
# Test losses: [-1.47324, -1.46118, -1.4514, -1.44542, -1.47957, -1.49169, -1.23137, -1.33489, -1.14547, -1.39057]
# AVG test loss: -1.39048
# Test S_nmad: 0.03635	Test out_rate: 0.07366
# ----------------------------------------
# Time: 60.647
# ========================================
# EPOCH #86/100:
# ----------------------------------------
# Trian losses: [-1.62724, -1.63092, -1.593, -1.57041, -1.62488, -1.64921, -1.26737, -1.41619, -1.19774, -1.50706]
# AVG train loss: -1.5084
# Train S_nmad: 0.03579	Train out_rate: 0.07244
# ----------------------------------------
# Test losses: [-1.47096, -1.45965, -1.45235, -1.4535, -1.48287, -1.46567, -1.23545, -1.35258, -1.18473, -1.41405]
# AVG test loss: -1.39718
# Test S_nmad: 0.03637	Test out_rate: 0.07363
# ----------------------------------------
# Time: 60.849
# ========================================
# EPOCH #87/100:
# ----------------------------------------
# Trian losses: [-1.61979, -1.62342, -1.54614, -1.56875, -1.62958, -1.65465, -1.27307, -1.42844, -1.21401, -1.52201]
# AVG train loss: -1.50799
# Train S_nmad: 0.03587	Train out_rate: 0.07242
# ----------------------------------------
# Test losses: [-1.45488, -1.4455, -1.46623, -1.44982, -1.47688, -1.44326, -1.23563, -1.34348, -1.19854, -1.41153]
# AVG test loss: -1.39257
# Test S_nmad: 0.03608	Test out_rate: 0.07335
# ----------------------------------------
# Time: 60.977
# ========================================
# EPOCH #88/100:
# ----------------------------------------
# Trian losses: [-1.62538, -1.62057, -1.48306, -1.56457, -1.6357, -1.65672, -1.27506, -1.43759, -1.23351, -1.52964]
# AVG train loss: -1.50618
# Train S_nmad: 0.03606	Train out_rate: 0.07245
# ----------------------------------------
# Test losses: [-1.4597, -1.43225, -1.38531, -1.44113, -1.48046, -1.45065, -1.23909, -1.32614, -1.20909, -1.40491]
# AVG test loss: -1.38287
# Test S_nmad: 0.03677	Test out_rate: 0.07345
# ----------------------------------------
# Time: 58.74
# ========================================
# EPOCH #89/100:
# ----------------------------------------
# Trian losses: [-1.64011, -1.6268, -1.48631, -1.56361, -1.63438, -1.65874, -1.27675, -1.43867, -1.2611, -1.54652]
# AVG train loss: -1.5133
# Train S_nmad: 0.03604	Train out_rate: 0.07231
# ----------------------------------------
# Test losses: [-1.47152, -1.45596, -1.43486, -1.43636, -1.48243, -1.46847, -1.24362, -1.34491, -1.22613, -1.39953]
# AVG test loss: -1.39638
# Test S_nmad: 0.03601	Test out_rate: 0.07382
# ----------------------------------------
# Time: 62.883
# ========================================
# EPOCH #90/100:
# ----------------------------------------
# Trian losses: [-1.63349, -1.61837, -1.53535, -1.56525, -1.63468, -1.65208, -1.27902, -1.43971, -1.28308, -1.55636]
# AVG train loss: -1.51974
# Train S_nmad: 0.03549	Train out_rate: 0.07225
# ----------------------------------------
# Test losses: [-1.46153, -1.47597, -1.46886, -1.43752, -1.48571, -1.47816, -1.24006, -1.34613, -1.24134, -1.41451]
# AVG test loss: -1.40498
# Test S_nmad: 0.03601	Test out_rate: 0.07379
# ----------------------------------------
# Time: 62.252
# ========================================
# EPOCH #91/100:
# ----------------------------------------
# Trian losses: [-1.62179, -1.59327, -1.54855, -1.5652, -1.63394, -1.644, -1.28345, -1.42731, -1.29069, -1.55705]
# AVG train loss: -1.51653
# Train S_nmad: 0.03566	Train out_rate: 0.07222
# ----------------------------------------
# Test losses: [-1.43812, -1.45205, -1.47974, -1.44337, -1.48671, -1.48362, -1.23674, -1.34231, -1.24763, -1.4138]
# AVG test loss: -1.40241
# Test S_nmad: 0.03613	Test out_rate: 0.07361
# ----------------------------------------
# Time: 63.635
# ========================================
# EPOCH #92/100:
# ----------------------------------------
# Trian losses: [-1.62224, -1.54445, -1.57098, -1.55107, -1.63248, -1.63442, -1.28944, -1.41892, -1.29327, -1.55355]
# AVG train loss: -1.51108
# Train S_nmad: 0.036	Train out_rate: 0.07206
# ----------------------------------------
# Test losses: [-1.46263, -1.42386, -1.4807, -1.45331, -1.48779, -1.47813, -1.24061, -1.32696, -1.24488, -1.40992]
# AVG test loss: -1.40088
# Test S_nmad: 0.03643	Test out_rate: 0.07356
# ----------------------------------------
# Time: 62.075
# ========================================
# EPOCH #93/100:
# ----------------------------------------
# Trian losses: [-1.63427, -1.51048, -1.59536, -1.51849, -1.62924, -1.61913, -1.29222, -1.42008, -1.2922, -1.555]
# AVG train loss: -1.50665
# Train S_nmad: 0.03585	Train out_rate: 0.07205
# ----------------------------------------
# Test losses: [-1.48037, -1.44803, -1.49143, -1.43924, -1.48555, -1.47897, -1.24027, -1.32141, -1.24913, -1.40727]
# AVG test loss: -1.40417
# Test S_nmad: 0.03622	Test out_rate: 0.07352
# ----------------------------------------
# Time: 63.231
# ========================================
# EPOCH #94/100:
# ----------------------------------------
# Trian losses: [-1.63249, -1.55195, -1.60496, -1.50264, -1.62788, -1.58867, -1.28903, -1.39729, -1.28921, -1.55507]
# AVG train loss: -1.50392
# Train S_nmad: 0.03561	Train out_rate: 0.07202
# ----------------------------------------
# Test losses: [-1.46964, -1.42503, -1.4911, -1.36472, -1.48273, -1.44972, -1.23797, -1.33326, -1.25483, -1.4055]
# AVG test loss: -1.39145
# Test S_nmad: 0.03605	Test out_rate: 0.07339
# ----------------------------------------
# Time: 61.974
# ========================================
# EPOCH #95/100:
# ----------------------------------------
# Trian losses: [-1.63491, -1.58259, -1.60298, -1.51582, -1.62757, -1.57646, -1.28495, -1.31862, -1.28198, -1.54467]
# AVG train loss: -1.49706
# Train S_nmad: 0.03612	Train out_rate: 0.07212
# ----------------------------------------
# Test losses: [-1.45721, -1.45556, -1.48781, -1.42398, -1.48745, -1.44316, -1.2349, -1.29011, -1.24272, -1.40581]
# AVG test loss: -1.39287
# Test S_nmad: 0.03659	Test out_rate: 0.07325
# ----------------------------------------
# Time: 62.064
# ========================================
# EPOCH #96/100:
# ----------------------------------------
# Trian losses: [-1.6458, -1.60627, -1.60611, -1.53673, -1.62057, -1.59348, -1.27947, -1.28035, -1.27408, -1.51915]
# AVG train loss: -1.4962
# Train S_nmad: 0.03759	Train out_rate: 0.07215
# ----------------------------------------
# Test losses: [-1.46559, -1.4463, -1.48742, -1.44549, -1.49675, -1.43737, -1.23755, -1.21957, -1.23142, -1.39917]
# AVG test loss: -1.38667
# Test S_nmad: 0.03593	Test out_rate: 0.07298
# ----------------------------------------
# Time: 64.265
# ========================================
# EPOCH #97/100:
# ----------------------------------------
# Trian losses: [-1.65068, -1.61576, -1.61493, -1.54388, -1.60511, -1.58961, -1.26702, -1.31587, -1.27466, -1.4978]
# AVG train loss: -1.49753
# Train S_nmad: 0.03659	Train out_rate: 0.07206
# ----------------------------------------
# Test losses: [-1.46681, -1.46745, -1.48805, -1.46051, -1.44668, -1.46257, -1.22234, -1.27697, -1.22138, -1.38241]
# AVG test loss: -1.38951
# Test S_nmad: 0.03611	Test out_rate: 0.07296
# ----------------------------------------
# Time: 64.603
# ========================================
# EPOCH #98/100:
# ----------------------------------------
# Trian losses: [-1.63909, -1.62773, -1.62199, -1.55023, -1.58182, -1.60324, -1.23697, -1.36462, -1.28321, -1.5102]
# AVG train loss: -1.50191
# Train S_nmad: 0.03581	Train out_rate: 0.07195
# ----------------------------------------
# Test losses: [-1.46425, -1.47417, -1.4852, -1.46315, -1.46241, -1.476, -1.2302, -1.31232, -1.22731, -1.40594]
# AVG test loss: -1.4001
# Test S_nmad: 0.03583	Test out_rate: 0.07314
# ----------------------------------------
# Time: 65.649
# ========================================
# EPOCH #99/100:
# ----------------------------------------
# Trian losses: [-1.64069, -1.62962, -1.62499, -1.54623, -1.59013, -1.61618, -1.19739, -1.40345, -1.27447, -1.52135]
# AVG train loss: -1.50445
# Train S_nmad: 0.03556	Train out_rate: 0.07194
# ----------------------------------------
# Test losses: [-1.45083, -1.46787, -1.48156, -1.46338, -1.46827, -1.47673, -1.17291, -1.33864, -1.23572, -1.39896]
# AVG test loss: -1.39549
# Test S_nmad: 0.03602	Test out_rate: 0.07342
# ----------------------------------------
# Time: 61.677
# ========================================
# EPOCH #100/100:
# ----------------------------------------
# Trian losses: [-1.6425, -1.6271, -1.6242, -1.53293, -1.61964, -1.6431, -1.18012, -1.42203, -1.25418, -1.53334]
# AVG train loss: -1.50792
# Train S_nmad: 0.03586	Train out_rate: 0.07195
# ----------------------------------------
# Test losses: [-1.44163, -1.46882, -1.47993, -1.42603, -1.48557, -1.49076, -1.15823, -1.35005, -1.25116, -1.42779]
# AVG test loss: -1.398
# Test S_nmad: 0.03594	Test out_rate: 0.07345
# ----------------------------------------
# Time: 64.064
# ========================================

# %%
ens.fit(
    X_train=X_01, 
    y_train=y_01,
    X_test=X_02,
    y_test=y_02,
    epochs=100, 
    batch_size=2**15,
    shuffle=True,
    optimizer=optimizer, 
    optimizer_args={'lr': 0.00005, 'weight_decay': 0.001},
    verbose=True,
    metrics={'S_nmad': sigma_nmad, 'out_rate': out_rate}
);
# Out:
# Device: cuda:0
# Test mode: True
# ========================================
# EPOCH #1/100:
# ----------------------------------------
# Trian losses: [-1.63229, -1.64166, -1.61785, -1.52805, -1.62678, -1.64253, -1.24648, -1.42389, -1.2921, -1.5399]
# AVG train loss: -1.51915
# Train S_nmad: 0.0358	Train out_rate: 0.07205
# ----------------------------------------
# Test losses: [-1.47205, -1.48193, -1.4877, -1.44688, -1.47872, -1.48302, -1.21171, -1.36367, -1.24616, -1.44012]
# AVG test loss: -1.4112
# Test S_nmad: 0.036	Test out_rate: 0.07303
# ----------------------------------------
# Time: 61.75
# ========================================
# EPOCH #2/100:
# ----------------------------------------
# Trian losses: [-1.64893, -1.63088, -1.60838, -1.53203, -1.62755, -1.66089, -1.267, -1.43825, -1.3027, -1.55625]
# AVG train loss: -1.52729
# Train S_nmad: 0.03602	Train out_rate: 0.07184
# ----------------------------------------
# Test losses: [-1.49088, -1.48004, -1.46794, -1.44523, -1.49296, -1.48497, -1.2425, -1.36625, -1.26119, -1.43581]
# AVG test loss: -1.41678
# Test S_nmad: 0.03621	Test out_rate: 0.07323
# ----------------------------------------
# Time: 63.11
# ========================================
# EPOCH #3/100:
# ----------------------------------------
# Trian losses: [-1.65463, -1.64117, -1.61948, -1.55699, -1.62522, -1.66749, -1.28988, -1.43584, -1.30446, -1.55918]
# AVG train loss: -1.53543
# Train S_nmad: 0.03553	Train out_rate: 0.07175
# ----------------------------------------
# Test losses: [-1.48955, -1.48062, -1.48217, -1.46265, -1.48654, -1.48092, -1.23823, -1.35258, -1.25615, -1.43116]
# AVG test loss: -1.41606
# Test S_nmad: 0.03608	Test out_rate: 0.07281
# ----------------------------------------
# Time: 62.269
# ========================================
# EPOCH #4/100:
# ----------------------------------------
# Trian losses: [-1.6582, -1.65499, -1.62581, -1.56074, -1.63201, -1.66989, -1.29154, -1.43062, -1.31041, -1.55935]
# AVG train loss: -1.53936
# Train S_nmad: 0.03531	Train out_rate: 0.07171
# ----------------------------------------
# Test losses: [-1.4854, -1.49001, -1.47833, -1.4676, -1.4992, -1.46807, -1.24541, -1.37084, -1.2621, -1.42484]
# AVG test loss: -1.41918
# Test S_nmad: 0.03572	Test out_rate: 0.07306
# ----------------------------------------
# Time: 63.927
# ========================================
# EPOCH #5/100:
# ----------------------------------------
# Trian losses: [-1.6639, -1.66034, -1.61439, -1.57201, -1.63514, -1.67078, -1.26039, -1.44224, -1.31536, -1.56454]
# AVG train loss: -1.53991
# Train S_nmad: 0.03534	Train out_rate: 0.07171
# ----------------------------------------
# Test losses: [-1.47312, -1.48431, -1.48474, -1.46805, -1.4966, -1.46247, -1.2568, -1.36808, -1.25544, -1.42737]
# AVG test loss: -1.4177
# Test S_nmad: 0.03567	Test out_rate: 0.07298
# ----------------------------------------
# Time: 61.524
# ========================================
# EPOCH #6/100:
# ----------------------------------------
# Trian losses: [-1.66537, -1.65668, -1.5996, -1.57862, -1.6479, -1.67064, -1.25795, -1.45378, -1.30672, -1.56527]
# AVG train loss: -1.54025
# Train S_nmad: 0.03517	Train out_rate: 0.0716
# ----------------------------------------
# Test losses: [-1.46571, -1.47752, -1.48126, -1.46676, -1.4996, -1.47678, -1.23202, -1.37602, -1.23981, -1.42291]
# AVG test loss: -1.41384
# Test S_nmad: 0.03561	Test out_rate: 0.0727
# ----------------------------------------
# Time: 63.178
# ========================================
# EPOCH #7/100:
# ----------------------------------------

# %%
print(f'Benchmark S_nmad:\t{round(sigma_nmad(train_20_35_02["Z"], train_20_35_02["max35_z"]), 5)}')
print(f'Benchmark out_rate:\t{round(out_rate(train_20_35_02["Z"], train_20_35_02["max35_z"]), 5)}')

# %%
# контролируемая рандомность
# нормализация, дроп ауты
# наглядные метрики

# %%
# dfs = []

# feas = pd.read_pickle(
#     f'{data_dir}/20_2-fold-cv/cv2_0/part-00000.features.gz_pkl',
#     compression='gzip'
# )[['ra', 'dec', 'zspec'] + features_list]
# preds = pd.read_pickle(
#     f'{data_dir}/20_2-fold-cv/cv2_0/part-00000.predictions.x1cv2_0.gz_pkl',
#     compression='gzip'
# )[[
#     'zoo_x1cv2_019_z_max', 'zoo_x1cv2_019_z_maxConf',
#     'zoo_x1cv2_021_z_max', 'zoo_x1cv2_021_z_maxConf',
#     'zoo_x1cv2_022_z_max', 'zoo_x1cv2_022_z_maxConf',
#     'zoo_x1cv2_035_z_max', 'zoo_x1cv2_035_z_maxConf'
# ]]
# df = feas.merge(preds, how='right', left_index=True, right_index=True)
# df.columns = ['RA', 'DEC', 'Z'] + features_list + models_cols
# df['fold'] = [0] * df.shape[0]
# dfs.append(df)

# feas = pd.read_pickle(
#     f'{data_dir}/20_2-fold-cv/cv2_1/part-00000.features.gz_pkl',
#     compression='gzip'
# )[['ra', 'dec', 'zspec'] + features_list]
# preds = pd.read_pickle(
#     f'{data_dir}/20_2-fold-cv/cv2_1/part-00000.predictions.x1cv2_1.gz_pkl',
#     compression='gzip'
# )[[
#     'zoo_x1cv2_119_z_max', 'zoo_x1cv2_119_z_maxConf',
#     'zoo_x1cv2_121_z_max', 'zoo_x1cv2_121_z_maxConf',
#     'zoo_x1cv2_122_z_max', 'zoo_x1cv2_122_z_maxConf',
#     'zoo_x1cv2_135_z_max', 'zoo_x1cv2_135_z_maxConf'
# ]]
# df = feas.merge(preds, how='right', left_index=True, right_index=True)
# df.columns = ['RA', 'DEC', 'Z'] + features_list + models_cols
# df['fold'] = [1] * df.shape[0]
# dfs.append(df)

# train_20 = pd.concat(dfs, axis=0)
# train_20.drop_duplicates(subset=['RA', 'DEC'], inplace=True, keep='last')
# train_20.sort_values(by=['RA'], inplace=True)
# train_20.reset_index(drop=True, inplace=True)
# train_20.replace(np.nan, None, inplace=True)
# train_20

# %%
# train_20.to_csv(f'{data_dir}/q_photo_z_train_20.csv', index=False)
